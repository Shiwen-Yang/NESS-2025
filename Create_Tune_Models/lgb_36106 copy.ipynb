# %%
import numpy as np 
import pandas as pd 
import sys
import os
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pylab as plt
import warnings
from datetime import datetime
import itertools
from scipy import stats

warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,20

# Add the grandparent directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../')))
from Utils import FE_helper as FE

# %%
# 2. Load the data
train_df = pd.read_csv('../Original_Data/train_2025.csv') 
test_df = pd.read_csv('../Original_Data/test_2025.csv')

train_df = FE.add_features(train_df)
test_df = FE.add_features(test_df)

test_id = test_df['claim_number']
train_id = train_df['claim_number']
target = train_df['fraud']

ignore_var = ['claim_date.is_weekend', 'claim_date.near_holiday', 'fraud']
train_df = FE.drop_ignored_columns(train_df, ignore_var)
test_df = FE.drop_ignored_columns(test_df, ignore_var)

# %%
def add_presence_columns(train_df, presence_info_df, verbose = False):
    """
    For each combo in presence_info_df, create a presence feature on train_df.
    
    Parameters:
    - train_df (pd.DataFrame): The training dataset.
    - presence_info_df (pd.DataFrame): DataFrame containing 'feature' column
      with names like 'feature1__feature2__feature3_present'.
    
    Returns:
    - pd.DataFrame: train_df with new presence columns added.
    """
    df_out = train_df.copy()
    
    for combo_str in presence_info_df['feature']:
        # Extract base combo name (strip trailing '_present')
        if combo_str.endswith('_present'):
            combo_base = combo_str[:-8]
        else:
            combo_base = combo_str
        
        # Split by '__' to get the individual features
        combo_features = combo_base.split('__')
        new_col_name = combo_base + '_present'  # keep consistent
        if verbose:
            print(f"Processing combo: {combo_features}")
        
        # Build tuple of feature values per row
        combo_tuples = train_df[combo_features].apply(tuple, axis=1)
        
        # Count how many times each tuple appears
        counts = combo_tuples.map(combo_tuples.value_counts())
        
        # Presence = appears more than once in the dataset
        df_out[new_col_name] = (counts > 1).astype(int)
    
    return df_out


def fit_presence_pca(train_df, present_cols, n_components=None, scale=True):
    """
    Fits PCA on presence feature columns in the training set.
    
    Parameters:
    - train_df (pd.DataFrame): Training dataset.
    - present_cols (list): List of column names for presence features.
    - n_components (int or None): Number of PCA components. If None, keep all.
    - scale (bool): Whether to standardize columns before PCA.
    
    Returns:
    - pca (PCA object): Fitted PCA object.
    - X_train_pca (np.ndarray): Transformed training set (PCA scores).
    - scaler (StandardScaler object or None): Fitted scaler if used, else None.
    """
    X = train_df[present_cols].values

    # Optionally scale features
    scaler = None
    if scale:
        scaler = StandardScaler()
        X = scaler.fit_transform(X)

    # Fit PCA
    pca = PCA(n_components=n_components, random_state=42)
    X_train_pca = pca.fit_transform(X)

    print(f"PCA fitted. Explained variance (first 10 components): {pca.explained_variance_ratio_[:10]}")
    return pca, X_train_pca, scaler



def fit_regular_transformer(train_df, presence_suffix='_present'):
    # Identify regular columns
    regular_cols = [col for col in train_df.columns if not col.endswith(presence_suffix)]
    
    # Split regular into categorical and numerical
    categorical_cols = train_df[regular_cols].select_dtypes(include=['object', 'category']).columns.tolist()
    numerical_cols = train_df[regular_cols].select_dtypes(include=['number']).columns.tolist()
    if 'claim_number' in numerical_cols:
        numerical_cols.remove('claim_number')
    
    # Initialize transformers
    onehot = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    scaler = StandardScaler()
    
    # Fit transformers
    onehot.fit(train_df[categorical_cols])
    scaler.fit(train_df[numerical_cols])
    
    # print(f"Fitted on {len(categorical_cols)} categorical and {len(numerical_cols)} numerical columns.")
    
    return onehot, scaler, categorical_cols, numerical_cols

def transform_regular_set(df, onehot, scaler, categorical_cols, numerical_cols):
    # Transform categorical
    cat_transformed = onehot.transform(df[categorical_cols])
    cat_df = pd.DataFrame(cat_transformed, columns=onehot.get_feature_names_out(categorical_cols), index=df.index)
    
    # Transform numerical
    num_transformed = scaler.transform(df[numerical_cols])
    num_df = pd.DataFrame(num_transformed, columns=numerical_cols, index=df.index)
    
    # Combine transformed parts
    transformed_df = pd.concat([num_df, cat_df], axis=1)
    
    # print(f"Transformed set shape: {transformed_df.shape}")
    return transformed_df

# %%
def objective(trial, train_df, presence_info_df, target, kfoldcv=5, drop=[]):
    # difference_min = trial.suggest_float('difference_min', 0.03, 0.07)
    # info_min = trial.suggest_float('info_min', 0.01, 0.05)
    difference_min = 0.05
    info_min = 0.03
    presence_info_df = presence_info_df[(np.abs(presence_info_df['difference']) > difference_min) 
                                        & (presence_info_df['info'] > info_min)]

    # Save the used values to trial attributes
    # trial.set_user_attr('difference_min', difference_min)
    # trial.set_user_attr('info_min', info_min)
    
    
    updated_train_df = add_presence_columns(train_df, presence_info_df)
    present_cols = [col for col in updated_train_df.columns if col.endswith('_present')]
    
    high_dim_cat_cols_to_drop = ['claim_date.day', 'claim_date.dayofweek', 'claim_date.weekofyear', 'claim_date.month', 'zero_payout']
    updated_train_df.drop(columns = high_dim_cat_cols_to_drop, inplace=True)
    
    # Step 1: Fit on training data
    onehot, scaler, cat_cols, num_cols = fit_regular_transformer(updated_train_df)

    # Step 2: Transform training set itself
    X_train_regular = transform_regular_set(updated_train_df, onehot, scaler, cat_cols, num_cols)
    
    full_train_df = pd.concat([X_train_regular, updated_train_df[present_cols]], axis=1)
    
    # Define hyperparameter space
    params = {
        'objective': 'binary',
        'metric': 'auc',
        'is_unbalance': True,
        'boosting': 'gbdt',
        # 'device': 'gpu', 
        'num_leaves': trial.suggest_int('num_leaves', 50, 90),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.3, 0.6),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.3, 0.9),
        'bagging_freq': trial.suggest_int('bagging_freq', 5, 25),
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1),
        'lambda_l1': trial.suggest_float('lambda_l1', 1e-3, 20.0, log=True),
        'lambda_l2': trial.suggest_float('lambda_l2', 1e-3, 25.0, log=True),
        'verbose': -1,
        'seed':69
    }

    skf = StratifiedKFold(n_splits=kfoldcv, shuffle=True, random_state=42)
    best_thresholds = []
    f1_scores = []

    for train_idx, val_idx in skf.split(full_train_df, target):
        X_train = full_train_df.iloc[train_idx].drop(columns=drop, errors='ignore')
        X_val = full_train_df.iloc[val_idx].drop(columns=drop, errors='ignore')
        y_train = target.iloc[train_idx]
        y_val = target.iloc[val_idx]

        lgb_train = lgb.Dataset(X_train, y_train)
        lgb_val = lgb.Dataset(X_val, y_val, reference=lgb_train)

        model = lgb.train(
                params,
                lgb_train,
                num_boost_round=2000,
                valid_sets=[lgb_val],
                callbacks=[lgb.early_stopping(stopping_rounds=50, verbose=False)]
            )

        # Predict + threshold tuning
        probs = model.predict(X_val, num_iteration=model.best_iteration)
        thresholds = np.linspace(0.1, 0.9, 50)
        f1s = [f1_score(y_val, probs > t) for t in thresholds]

        best_f1 = max(f1s)
        best_threshold = thresholds[np.argmax(f1s)]

        f1_scores.append(best_f1)
        best_thresholds.append(best_threshold)

    mean_f1 = np.mean(f1_scores)
    mean_threshold = np.mean(best_thresholds)

    trial.set_user_attr('mean_threshold', mean_threshold)
    trial.set_user_attr('f1_per_fold', f1_scores)

    return mean_f1

# %%
presence_info_df_3 = pd.read_csv('logs/subset_info_3.csv')
# Run Optuna
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)
study.optimize(lambda trial: objective(trial, train_df, presence_info_df_3, target, kfoldcv= 5),
                n_trials=350)

best_f1 = study.best_value
# Out:
# [I 2025-05-06 23:16:33,605] A new study created in memory with name: no-name-df106f50-cd2a-4731-b039-c49fdb22c249
# [I 2025-05-06 23:16:47,491] Trial 0 finished with value: 0.3590430370316729 and parameters: {'num_leaves': 63, 'feature_fraction': 0.36243835556914783, 'bagging_fraction': 0.35301386803461887, 'bagging_freq': 7, 'learning_rate': 0.06893248208142541, 'lambda_l1': 1.7262386475520366, 'lambda_l2': 0.16880017632158723}. Best is trial 0 with value: 0.3590430370316729.
# [I 2025-05-06 23:17:02,381] Trial 1 finished with value: 0.3586454243766305 and parameters: {'num_leaves': 66, 'feature_fraction': 0.5443695948486299, 'bagging_fraction': 0.3863385071958297, 'bagging_freq': 14, 'learning_rate': 0.053677782933964795, 'lambda_l1': 0.0030624648983531753, 'lambda_l2': 0.001039954431997392}. Best is trial 0 with value: 0.3590430370316729.
# [I 2025-05-06 23:17:13,538] Trial 2 finished with value: 0.3683525571730963 and parameters: {'num_leaves': 83, 'feature_fraction': 0.39677118211979145, 'bagging_fraction': 0.8654345955669926, 'bagging_freq': 23, 'learning_rate': 0.06709818579784656, 'lambda_l1': 0.03292337403480974, 'lambda_l2': 24.82998278168824}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:17:28,685] Trial 3 finished with value: 0.362807521024253 and parameters: {'num_leaves': 86, 'feature_fraction': 0.522113673219768, 'bagging_fraction': 0.7743404187221923, 'bagging_freq': 16, 'learning_rate': 0.053902578686217985, 'lambda_l1': 0.007756164818225646, 'lambda_l2': 1.7585797191285275}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:17:43,260] Trial 4 finished with value: 0.3588085226915939 and parameters: {'num_leaves': 51, 'feature_fraction': 0.46317640745423594, 'bagging_fraction': 0.7092350578861, 'bagging_freq': 24, 'learning_rate': 0.08085952104158002, 'lambda_l1': 0.11875545519766104, 'lambda_l2': 0.05324038123771517}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:17:57,783] Trial 5 finished with value: 0.36438846435934125 and parameters: {'num_leaves': 68, 'feature_fraction': 0.40620563521956404, 'bagging_fraction': 0.6120793260852022, 'bagging_freq': 21, 'learning_rate': 0.03857405133288374, 'lambda_l1': 0.02245827862383947, 'lambda_l2': 0.08121008833223509}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:18:12,008] Trial 6 finished with value: 0.3623492532353294 and parameters: {'num_leaves': 58, 'feature_fraction': 0.562504323388755, 'bagging_fraction': 0.7372810572522799, 'bagging_freq': 22, 'learning_rate': 0.09543513792658244, 'lambda_l1': 4.633766995372371, 'lambda_l2': 0.0011184249903989022}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:18:35,454] Trial 7 finished with value: 0.36574309379467423 and parameters: {'num_leaves': 61, 'feature_fraction': 0.42461537249835885, 'bagging_fraction': 0.5497746293322432, 'bagging_freq': 25, 'learning_rate': 0.025014798040976553, 'lambda_l1': 0.020503422409615425, 'lambda_l2': 0.2813220918246956}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:18:49,505] Trial 8 finished with value: 0.367326184519627 and parameters: {'num_leaves': 83, 'feature_fraction': 0.3391090427995978, 'bagging_fraction': 0.3374560280995954, 'bagging_freq': 10, 'learning_rate': 0.04435053522321272, 'lambda_l1': 7.2813841935341905, 'lambda_l2': 0.007496437065300469}. Best is trial 2 with value: 0.3683525571730963.
# [I 2025-05-06 23:19:10,397] Trial 9 finished with value: 0.3686137935398737 and parameters: {'num_leaves': 61, 'feature_fraction': 0.4138817663078985, 'bagging_fraction': 0.3685011123258408, 'bagging_freq': 20, 'learning_rate': 0.04780554528634192, 'lambda_l1': 19.726714791135826, 'lambda_l2': 0.013313163835254455}. Best is trial 9 with value: 0.3686137935398737.
# [I 2025-05-06 23:19:40,404] Trial 10 finished with value: 0.36973396381744245 and parameters: {'num_leaves': 76, 'feature_fraction': 0.30619947317281737, 'bagging_fraction': 0.4820041739544494, 'bagging_freq': 18, 'learning_rate': 0.005426496835209731, 'lambda_l1': 0.5722318649971424, 'lambda_l2': 0.011644011824614336}. Best is trial 10 with value: 0.36973396381744245.
# [I 2025-05-06 23:20:13,957] Trial 11 finished with value: 0.3662523752778716 and parameters: {'num_leaves': 76, 'feature_fraction': 0.3153603641534868, 'bagging_fraction': 0.4768535779441262, 'bagging_freq': 18, 'learning_rate': 0.007915172699582695, 'lambda_l1': 0.6218672132798768, 'lambda_l2': 0.010471561794374454}. Best is trial 10 with value: 0.36973396381744245.
# [I 2025-05-06 23:20:42,913] Trial 12 finished with value: 0.36916810174452774 and parameters: {'num_leaves': 74, 'feature_fraction': 0.48398463880411974, 'bagging_fraction': 0.45096811361894795, 'bagging_freq': 19, 'learning_rate': 0.014940566996517303, 'lambda_l1': 19.866614744419543, 'lambda_l2': 0.011241874416978107}. Best is trial 10 with value: 0.36973396381744245.
# [I 2025-05-06 23:21:10,992] Trial 13 finished with value: 0.36877453529904203 and parameters: {'num_leaves': 76, 'feature_fraction': 0.4887367139397181, 'bagging_fraction': 0.47745314834967256, 'bagging_freq': 13, 'learning_rate': 0.0109891400565795, 'lambda_l1': 0.3346874743260571, 'lambda_l2': 0.004663927893665757}. Best is trial 10 with value: 0.36973396381744245.
# [I 2025-05-06 23:21:34,553] Trial 14 finished with value: 0.36199692604112543 and parameters: {'num_leaves': 74, 'feature_fraction': 0.5968350620963906, 'bagging_fraction': 0.45778534188941206, 'bagging_freq': 18, 'learning_rate': 0.024012359800834604, 'lambda_l1': 1.3904227723854392, 'lambda_l2': 0.030877814636553733}. Best is trial 10 with value: 0.36973396381744245.
# [I 2025-05-06 23:21:57,484] Trial 15 finished with value: 0.3709250732187039 and parameters: {'num_leaves': 72, 'feature_fraction': 0.4633484821265022, 'bagging_fraction': 0.5817042065079796, 'bagging_freq': 17, 'learning_rate': 0.023127548089943425, 'lambda_l1': 0.12326053364147933, 'lambda_l2': 1.6716370241447756}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:22:20,763] Trial 16 finished with value: 0.3669200009897092 and parameters: {'num_leaves': 80, 'feature_fraction': 0.3612723788212157, 'bagging_fraction': 0.6067607173097191, 'bagging_freq': 11, 'learning_rate': 0.02670482901428322, 'lambda_l1': 0.09193288003607476, 'lambda_l2': 1.1698215824807454}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:22:38,586] Trial 17 finished with value: 0.370752470831326 and parameters: {'num_leaves': 89, 'feature_fraction': 0.4470582628786872, 'bagging_fraction': 0.5398500204217267, 'bagging_freq': 16, 'learning_rate': 0.032769361748638266, 'lambda_l1': 0.3019431787935838, 'lambda_l2': 11.076844476862957}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:23:04,957] Trial 18 finished with value: 0.3690663745550239 and parameters: {'num_leaves': 90, 'feature_fraction': 0.4503245634648949, 'bagging_fraction': 0.6578987153258669, 'bagging_freq': 16, 'learning_rate': 0.028105087860819333, 'lambda_l1': 0.075439048711961, 'lambda_l2': 14.840546829238146}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:23:25,107] Trial 19 finished with value: 0.36558684217489035 and parameters: {'num_leaves': 90, 'feature_fraction': 0.508408701958301, 'bagging_fraction': 0.5400606714831713, 'bagging_freq': 5, 'learning_rate': 0.03628528541597103, 'lambda_l1': 0.0012744876066845237, 'lambda_l2': 5.6100504865704055}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:23:41,087] Trial 20 finished with value: 0.3696722159419491 and parameters: {'num_leaves': 53, 'feature_fraction': 0.37500375036823463, 'bagging_fraction': 0.6708969664691209, 'bagging_freq': 12, 'learning_rate': 0.01864504924552796, 'lambda_l1': 0.2460245710753486, 'lambda_l2': 0.7594919360586525}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:24:01,933] Trial 21 finished with value: 0.357128726266008 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3070133742204199, 'bagging_fraction': 0.5619234015872513, 'bagging_freq': 16, 'learning_rate': 0.005222769028111225, 'lambda_l1': 0.7269242122784091, 'lambda_l2': 4.9099364976680056}. Best is trial 15 with value: 0.3709250732187039.
# [I 2025-05-06 23:24:24,656] Trial 22 finished with value: 0.3749498754429387 and parameters: {'num_leaves': 80, 'feature_fraction': 0.43852938623323606, 'bagging_fraction': 0.5169398623931981, 'bagging_freq': 17, 'learning_rate': 0.01748258409699211, 'lambda_l1': 0.22617638728847328, 'lambda_l2': 3.998070626172179}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:24:47,280] Trial 23 finished with value: 0.36603875344551673 and parameters: {'num_leaves': 80, 'feature_fraction': 0.4345972098886844, 'bagging_fraction': 0.5273092581339089, 'bagging_freq': 14, 'learning_rate': 0.03412824232365365, 'lambda_l1': 0.2203471575405549, 'lambda_l2': 4.192716356343925}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:25:12,851] Trial 24 finished with value: 0.3647475184517555 and parameters: {'num_leaves': 86, 'feature_fraction': 0.47133214537753676, 'bagging_fraction': 0.40774875526734244, 'bagging_freq': 9, 'learning_rate': 0.017620810337764987, 'lambda_l1': 0.04469538986783454, 'lambda_l2': 10.145260845099902}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:25:36,040] Trial 25 finished with value: 0.36471228053059546 and parameters: {'num_leaves': 80, 'feature_fraction': 0.4455077719316561, 'bagging_fraction': 0.5863261457427811, 'bagging_freq': 15, 'learning_rate': 0.03337551239774397, 'lambda_l1': 1.9311324023986205, 'lambda_l2': 0.48266338671084075}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:25:57,275] Trial 26 finished with value: 0.36913374538350063 and parameters: {'num_leaves': 87, 'feature_fraction': 0.5064142865090626, 'bagging_fraction': 0.6465483886007422, 'bagging_freq': 17, 'learning_rate': 0.018847720488796852, 'lambda_l1': 0.16424221277175027, 'lambda_l2': 1.8167940430343381}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:26:15,942] Trial 27 finished with value: 0.3631881629037087 and parameters: {'num_leaves': 83, 'feature_fraction': 0.389588160508432, 'bagging_fraction': 0.5135854996854011, 'bagging_freq': 20, 'learning_rate': 0.042944714622525255, 'lambda_l1': 0.011557595620821856, 'lambda_l2': 2.826296247019948}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:26:30,991] Trial 28 finished with value: 0.36426726961644873 and parameters: {'num_leaves': 69, 'feature_fraction': 0.45715789662866024, 'bagging_fraction': 0.3086392201575966, 'bagging_freq': 14, 'learning_rate': 0.028086675567696638, 'lambda_l1': 0.06914232418295246, 'lambda_l2': 9.711366751256211}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:26:45,704] Trial 29 finished with value: 0.3614984954744401 and parameters: {'num_leaves': 65, 'feature_fraction': 0.4846924312104208, 'bagging_fraction': 0.40927544628530405, 'bagging_freq': 7, 'learning_rate': 0.0662467687264818, 'lambda_l1': 0.39402920830483623, 'lambda_l2': 0.16355801944044382}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:27:06,985] Trial 30 finished with value: 0.3675187460883832 and parameters: {'num_leaves': 71, 'feature_fraction': 0.4313183692790334, 'bagging_fraction': 0.8165071111436369, 'bagging_freq': 20, 'learning_rate': 0.013743693495195726, 'lambda_l1': 1.0666838558229448, 'lambda_l2': 0.7465578603187308}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:27:41,330] Trial 31 finished with value: 0.36358356261101765 and parameters: {'num_leaves': 77, 'feature_fraction': 0.3408685553680719, 'bagging_fraction': 0.4971758441574843, 'bagging_freq': 18, 'learning_rate': 0.005112781819389628, 'lambda_l1': 3.2563526765622166, 'lambda_l2': 0.3438293464806658}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:28:02,757] Trial 32 finished with value: 0.36929837865243126 and parameters: {'num_leaves': 79, 'feature_fraction': 0.3573399213631521, 'bagging_fraction': 0.43478915051549527, 'bagging_freq': 17, 'learning_rate': 0.02135149699778309, 'lambda_l1': 0.4805830472670035, 'lambda_l2': 22.67998175400673}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:28:38,027] Trial 33 finished with value: 0.36972269212620884 and parameters: {'num_leaves': 73, 'feature_fraction': 0.5433615034505104, 'bagging_fraction': 0.5728155195153521, 'bagging_freq': 15, 'learning_rate': 0.0099739171673731, 'lambda_l1': 0.17863534516821952, 'lambda_l2': 2.8343043515486226}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:29:02,916] Trial 34 finished with value: 0.36503558413496995 and parameters: {'num_leaves': 67, 'feature_fraction': 0.3893823463280859, 'bagging_fraction': 0.6188084100025997, 'bagging_freq': 17, 'learning_rate': 0.030802337723576746, 'lambda_l1': 0.7402954750499009, 'lambda_l2': 0.0025451500058422108}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:29:19,915] Trial 35 finished with value: 0.3621919535383235 and parameters: {'num_leaves': 83, 'feature_fraction': 0.5208206096716862, 'bagging_fraction': 0.5025895912827143, 'bagging_freq': 22, 'learning_rate': 0.05524844365710972, 'lambda_l1': 0.04428414080899508, 'lambda_l2': 8.096853534676699}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:29:37,148] Trial 36 finished with value: 0.36322578294959224 and parameters: {'num_leaves': 70, 'feature_fraction': 0.4131324169891647, 'bagging_fraction': 0.4275073422695204, 'bagging_freq': 13, 'learning_rate': 0.01172185590963222, 'lambda_l1': 0.12473198931804357, 'lambda_l2': 0.10338548274805112}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:29:53,020] Trial 37 finished with value: 0.3700335093170446 and parameters: {'num_leaves': 86, 'feature_fraction': 0.32722301895276573, 'bagging_fraction': 0.6288221078168588, 'bagging_freq': 19, 'learning_rate': 0.022059453823622312, 'lambda_l1': 2.1164959187790235, 'lambda_l2': 0.02260696269172305}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:30:05,733] Trial 38 finished with value: 0.3658272689821134 and parameters: {'num_leaves': 88, 'feature_fraction': 0.4673718896964472, 'bagging_fraction': 0.7120066356682905, 'bagging_freq': 22, 'learning_rate': 0.03996474968276932, 'lambda_l1': 2.2336419447042526, 'lambda_l2': 1.6518169464333878}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:30:27,990] Trial 39 finished with value: 0.36513699116900245 and parameters: {'num_leaves': 85, 'feature_fraction': 0.5502879802392306, 'bagging_fraction': 0.6334257513410324, 'bagging_freq': 19, 'learning_rate': 0.02179681043021899, 'lambda_l1': 0.01702403128011205, 'lambda_l2': 0.03842022408624678}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:30:48,879] Trial 40 finished with value: 0.3698052562626102 and parameters: {'num_leaves': 85, 'feature_fraction': 0.43941358049987794, 'bagging_fraction': 0.690779059287972, 'bagging_freq': 24, 'learning_rate': 0.06187788161792286, 'lambda_l1': 9.777891670511847, 'lambda_l2': 16.643068465709312}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:31:03,731] Trial 41 finished with value: 0.3722698835963182 and parameters: {'num_leaves': 85, 'feature_fraction': 0.4390466956765357, 'bagging_fraction': 0.6906299651978014, 'bagging_freq': 24, 'learning_rate': 0.05683033407833889, 'lambda_l1': 10.09361978353015, 'lambda_l2': 24.824311607949305}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:31:21,071] Trial 42 finished with value: 0.3679013342744364 and parameters: {'num_leaves': 88, 'feature_fraction': 0.4207752161525564, 'bagging_fraction': 0.7889649336122935, 'bagging_freq': 21, 'learning_rate': 0.07922076784348511, 'lambda_l1': 8.529436015658215, 'lambda_l2': 22.342116215730158}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:31:41,146] Trial 43 finished with value: 0.36698802067690217 and parameters: {'num_leaves': 84, 'feature_fraction': 0.46577854525628487, 'bagging_fraction': 0.7404174972449851, 'bagging_freq': 24, 'learning_rate': 0.05086087125401606, 'lambda_l1': 4.856782313665439, 'lambda_l2': 12.68169143135282}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:31:54,316] Trial 44 finished with value: 0.36346363679064086 and parameters: {'num_leaves': 89, 'feature_fraction': 0.4985751436343444, 'bagging_fraction': 0.562263294138067, 'bagging_freq': 25, 'learning_rate': 0.05964477718455287, 'lambda_l1': 0.0046296902112191556, 'lambda_l2': 6.241046660787218}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:32:09,604] Trial 45 finished with value: 0.3725753015824699 and parameters: {'num_leaves': 83, 'feature_fraction': 0.41005144491757545, 'bagging_fraction': 0.6011850955594339, 'bagging_freq': 16, 'learning_rate': 0.07403887781599938, 'lambda_l1': 4.164231678693036, 'lambda_l2': 3.260872118109574}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:32:24,755] Trial 46 finished with value: 0.3694547552624506 and parameters: {'num_leaves': 78, 'feature_fraction': 0.40746459066218327, 'bagging_fraction': 0.5933856953981568, 'bagging_freq': 16, 'learning_rate': 0.07942060250254952, 'lambda_l1': 12.77897762311509, 'lambda_l2': 3.37657615005857}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:32:34,561] Trial 47 finished with value: 0.36575796297642016 and parameters: {'num_leaves': 81, 'feature_fraction': 0.4236123616962748, 'bagging_fraction': 0.5372120575604187, 'bagging_freq': 15, 'learning_rate': 0.08697254810856157, 'lambda_l1': 3.7687577085782493, 'lambda_l2': 7.335212236541918}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:32:47,041] Trial 48 finished with value: 0.3666377322522708 and parameters: {'num_leaves': 82, 'feature_fraction': 0.3784253632416288, 'bagging_fraction': 0.8717241883399494, 'bagging_freq': 14, 'learning_rate': 0.07001384094237784, 'lambda_l1': 0.2729187685763067, 'lambda_l2': 1.9863382222514525}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:32:58,120] Trial 49 finished with value: 0.3669299633818653 and parameters: {'num_leaves': 63, 'feature_fraction': 0.451950270426804, 'bagging_fraction': 0.743626385151504, 'bagging_freq': 12, 'learning_rate': 0.07356262895775244, 'lambda_l1': 5.584063562757764, 'lambda_l2': 12.69613227451227}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:33:10,561] Trial 50 finished with value: 0.3631509834650638 and parameters: {'num_leaves': 75, 'feature_fraction': 0.39745208726831577, 'bagging_fraction': 0.6769423097737002, 'bagging_freq': 17, 'learning_rate': 0.08753816313271874, 'lambda_l1': 0.03844048165950375, 'lambda_l2': 1.0111118617819574}. Best is trial 22 with value: 0.3749498754429387.
# [I 2025-05-06 23:33:35,181] Trial 51 finished with value: 0.37532893888651936 and parameters: {'num_leaves': 85, 'feature_fraction': 0.3271944488877518, 'bagging_fraction': 0.6130409482722502, 'bagging_freq': 19, 'learning_rate': 0.04357423433785507, 'lambda_l1': 12.108176914152095, 'lambda_l2': 24.92992704259191}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:33:58,421] Trial 52 finished with value: 0.37438858391567276 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4420457453486519, 'bagging_fraction': 0.5990402716494025, 'bagging_freq': 16, 'learning_rate': 0.04599214524736047, 'lambda_l1': 13.80307750660797, 'lambda_l2': 18.286390027272198}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:34:19,909] Trial 53 finished with value: 0.37463701949335415 and parameters: {'num_leaves': 82, 'feature_fraction': 0.43125050114530306, 'bagging_fraction': 0.5874533500854885, 'bagging_freq': 18, 'learning_rate': 0.04660384438293709, 'lambda_l1': 17.94482584794478, 'lambda_l2': 21.422098569620093}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:34:44,356] Trial 54 finished with value: 0.37122264292256696 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4001792394007364, 'bagging_fraction': 0.607218688405862, 'bagging_freq': 21, 'learning_rate': 0.045709971677678776, 'lambda_l1': 14.293757230916285, 'lambda_l2': 23.828767528628234}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:35:00,894] Trial 55 finished with value: 0.3714796095035282 and parameters: {'num_leaves': 78, 'feature_fraction': 0.47743352622964463, 'bagging_fraction': 0.6469687108872302, 'bagging_freq': 19, 'learning_rate': 0.04894975118419331, 'lambda_l1': 13.872985791199863, 'lambda_l2': 17.732969811704372}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:35:24,858] Trial 56 finished with value: 0.37178637117522684 and parameters: {'num_leaves': 84, 'feature_fraction': 0.42360555201049466, 'bagging_fraction': 0.7139868375712068, 'bagging_freq': 18, 'learning_rate': 0.05578262290389162, 'lambda_l1': 19.422022844989357, 'lambda_l2': 16.0586397696593}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:35:38,568] Trial 57 finished with value: 0.3716700606571766 and parameters: {'num_leaves': 81, 'feature_fraction': 0.35015350026638875, 'bagging_fraction': 0.5969126714875352, 'bagging_freq': 16, 'learning_rate': 0.058448545085932266, 'lambda_l1': 7.744208469177115, 'lambda_l2': 8.005295972827911}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:35:56,424] Trial 58 finished with value: 0.3683817957114141 and parameters: {'num_leaves': 87, 'feature_fraction': 0.37246372580668746, 'bagging_fraction': 0.6927793221096252, 'bagging_freq': 22, 'learning_rate': 0.09964320500087703, 'lambda_l1': 5.9832145360414755, 'lambda_l2': 4.24730259746592}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:36:16,590] Trial 59 finished with value: 0.36999488619200177 and parameters: {'num_leaves': 85, 'feature_fraction': 0.41450623560066796, 'bagging_fraction': 0.5632597563051217, 'bagging_freq': 23, 'learning_rate': 0.04128838851397404, 'lambda_l1': 3.3652663551568827, 'lambda_l2': 5.559635238369723}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:36:41,113] Trial 60 finished with value: 0.3691369141882991 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4364705973296729, 'bagging_fraction': 0.6260911068526155, 'bagging_freq': 20, 'learning_rate': 0.03744642240486462, 'lambda_l1': 10.823151108779914, 'lambda_l2': 12.53511972947715}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:37:02,022] Trial 61 finished with value: 0.37469328914747446 and parameters: {'num_leaves': 84, 'feature_fraction': 0.4222658767402643, 'bagging_fraction': 0.7131290774143764, 'bagging_freq': 18, 'learning_rate': 0.05228203573715948, 'lambda_l1': 15.307690159383107, 'lambda_l2': 17.670023396602932}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:37:24,370] Trial 62 finished with value: 0.3734554157501765 and parameters: {'num_leaves': 79, 'feature_fraction': 0.4420531472747804, 'bagging_fraction': 0.6537956795922332, 'bagging_freq': 18, 'learning_rate': 0.05186195591819917, 'lambda_l1': 19.161336807715994, 'lambda_l2': 24.097579012595535}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:37:40,110] Trial 63 finished with value: 0.3708496830008879 and parameters: {'num_leaves': 79, 'feature_fraction': 0.4587856298442829, 'bagging_fraction': 0.6523689922923502, 'bagging_freq': 18, 'learning_rate': 0.04658227709603119, 'lambda_l1': 19.9565305577861, 'lambda_l2': 9.823871945336583}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:38:00,638] Trial 64 finished with value: 0.36910637456848716 and parameters: {'num_leaves': 77, 'feature_fraction': 0.3870958051935925, 'bagging_fraction': 0.6655405944979405, 'bagging_freq': 19, 'learning_rate': 0.051861983611447206, 'lambda_l1': 14.933119326204295, 'lambda_l2': 18.008450604164338}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:38:17,253] Trial 65 finished with value: 0.36765492058225624 and parameters: {'num_leaves': 81, 'feature_fraction': 0.4277046389298586, 'bagging_fraction': 0.5243828182197949, 'bagging_freq': 18, 'learning_rate': 0.06439321423874483, 'lambda_l1': 6.550473045078009, 'lambda_l2': 15.767107265182167}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:38:37,041] Trial 66 finished with value: 0.36862064163112224 and parameters: {'num_leaves': 83, 'feature_fraction': 0.44680752555637177, 'bagging_fraction': 0.7595654483513518, 'bagging_freq': 17, 'learning_rate': 0.05089846812323621, 'lambda_l1': 8.70767129820623, 'lambda_l2': 8.233774351256079}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:38:55,752] Trial 67 finished with value: 0.36776596509740334 and parameters: {'num_leaves': 79, 'feature_fraction': 0.41045860996828404, 'bagging_fraction': 0.5755150292463905, 'bagging_freq': 15, 'learning_rate': 0.04371313691799533, 'lambda_l1': 2.8386526285544664, 'lambda_l2': 3.339335305892085}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:39:07,814] Trial 68 finished with value: 0.37012422273656054 and parameters: {'num_leaves': 87, 'feature_fraction': 0.4538758394444618, 'bagging_fraction': 0.6082344910085685, 'bagging_freq': 16, 'learning_rate': 0.05330497331230615, 'lambda_l1': 4.713890409309143, 'lambda_l2': 18.502573636212162}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:39:24,517] Trial 69 finished with value: 0.37008891532259963 and parameters: {'num_leaves': 56, 'feature_fraction': 0.48032030929060765, 'bagging_fraction': 0.5495313627940557, 'bagging_freq': 19, 'learning_rate': 0.0481498747329549, 'lambda_l1': 1.2903762499535576, 'lambda_l2': 11.445553232985903}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:39:43,937] Trial 70 finished with value: 0.3704896341556402 and parameters: {'num_leaves': 84, 'feature_fraction': 0.3011916953428124, 'bagging_fraction': 0.4714586052699652, 'bagging_freq': 20, 'learning_rate': 0.0620336402785818, 'lambda_l1': 15.999496796088044, 'lambda_l2': 5.514494437305661}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:40:02,930] Trial 71 finished with value: 0.37388973985376905 and parameters: {'num_leaves': 85, 'feature_fraction': 0.4382056809458417, 'bagging_fraction': 0.6935244461495667, 'bagging_freq': 17, 'learning_rate': 0.057083259711905705, 'lambda_l1': 10.224577005743882, 'lambda_l2': 19.329387153923868}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:40:24,261] Trial 72 finished with value: 0.3725315267986718 and parameters: {'num_leaves': 81, 'feature_fraction': 0.43904576783251525, 'bagging_fraction': 0.6371123371036522, 'bagging_freq': 17, 'learning_rate': 0.07192815580080654, 'lambda_l1': 11.384834752333248, 'lambda_l2': 23.7930008919127}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:40:39,093] Trial 73 finished with value: 0.3693048326987788 and parameters: {'num_leaves': 86, 'feature_fraction': 0.5928536841200143, 'bagging_fraction': 0.7276775484113208, 'bagging_freq': 18, 'learning_rate': 0.040737786809729684, 'lambda_l1': 7.267740340248371, 'lambda_l2': 10.16698395249376}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:40:58,184] Trial 74 finished with value: 0.37274811580077644 and parameters: {'num_leaves': 83, 'feature_fraction': 0.3178343868757143, 'bagging_fraction': 0.7947518940813059, 'bagging_freq': 18, 'learning_rate': 0.07577706203656637, 'lambda_l1': 15.059819639422967, 'lambda_l2': 6.947160294423016}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:41:23,949] Trial 75 finished with value: 0.3726309323283074 and parameters: {'num_leaves': 80, 'feature_fraction': 0.47178599788346137, 'bagging_fraction': 0.7937441167686511, 'bagging_freq': 18, 'learning_rate': 0.035790714283434756, 'lambda_l1': 19.837008245697213, 'lambda_l2': 13.420218141923513}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:41:38,586] Trial 76 finished with value: 0.36965010289193573 and parameters: {'num_leaves': 88, 'feature_fraction': 0.33140755451917225, 'bagging_fraction': 0.8355335051325815, 'bagging_freq': 20, 'learning_rate': 0.04442633741319632, 'lambda_l1': 0.0012905170806855727, 'lambda_l2': 7.264538866045619}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:41:58,191] Trial 77 finished with value: 0.3715050317732736 and parameters: {'num_leaves': 84, 'feature_fraction': 0.34594337311813705, 'bagging_fraction': 0.8452723096030083, 'bagging_freq': 21, 'learning_rate': 0.05344806295397834, 'lambda_l1': 10.865704377533698, 'lambda_l2': 17.366897817661698}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:42:13,757] Trial 78 finished with value: 0.37156569393522654 and parameters: {'num_leaves': 90, 'feature_fraction': 0.3237755626375104, 'bagging_fraction': 0.6696946507651622, 'bagging_freq': 19, 'learning_rate': 0.049929994295825654, 'lambda_l1': 15.575313157919663, 'lambda_l2': 24.370335384991954}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:42:33,006] Trial 79 finished with value: 0.36919819666462833 and parameters: {'num_leaves': 75, 'feature_fraction': 0.30966862552861185, 'bagging_fraction': 0.7829154481100232, 'bagging_freq': 17, 'learning_rate': 0.06736735679365055, 'lambda_l1': 6.949242347535172, 'lambda_l2': 9.254923907765233}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:42:58,327] Trial 80 finished with value: 0.3715411299808817 and parameters: {'num_leaves': 82, 'feature_fraction': 0.3169720579933729, 'bagging_fraction': 0.698784976918882, 'bagging_freq': 17, 'learning_rate': 0.03190283647848895, 'lambda_l1': 2.7639620559971485, 'lambda_l2': 13.892170766825814}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:43:22,405] Trial 81 finished with value: 0.37199499771650907 and parameters: {'num_leaves': 80, 'feature_fraction': 0.4950828836532936, 'bagging_fraction': 0.8138887068444529, 'bagging_freq': 18, 'learning_rate': 0.03612996778967495, 'lambda_l1': 18.78601460978063, 'lambda_l2': 13.480725885875115}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:43:46,844] Trial 82 finished with value: 0.36987622703906636 and parameters: {'num_leaves': 77, 'feature_fraction': 0.4617661803181424, 'bagging_fraction': 0.8879480904384754, 'bagging_freq': 19, 'learning_rate': 0.03875290466175781, 'lambda_l1': 10.80933780836115, 'lambda_l2': 6.8673826727885645}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:44:09,760] Trial 83 finished with value: 0.3734647095825457 and parameters: {'num_leaves': 79, 'feature_fraction': 0.42863192187198096, 'bagging_fraction': 0.7616898336719509, 'bagging_freq': 18, 'learning_rate': 0.045719881599286194, 'lambda_l1': 13.253506001917154, 'lambda_l2': 18.40367012240603}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:44:31,211] Trial 84 finished with value: 0.37329511298372725 and parameters: {'num_leaves': 78, 'feature_fraction': 0.43188552387841916, 'bagging_fraction': 0.7232586024575631, 'bagging_freq': 18, 'learning_rate': 0.04727057824548686, 'lambda_l1': 13.823766309365674, 'lambda_l2': 4.37738101112539}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:44:53,711] Trial 85 finished with value: 0.3708155877177336 and parameters: {'num_leaves': 78, 'feature_fraction': 0.4304392854446178, 'bagging_fraction': 0.7328674271013348, 'bagging_freq': 15, 'learning_rate': 0.046583271085186825, 'lambda_l1': 8.726053552586198, 'lambda_l2': 18.833376435728198}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:45:11,084] Trial 86 finished with value: 0.37335144131403375 and parameters: {'num_leaves': 74, 'feature_fraction': 0.41768659577029066, 'bagging_fraction': 0.7581920303231723, 'bagging_freq': 16, 'learning_rate': 0.05945425916669335, 'lambda_l1': 5.613523336143416, 'lambda_l2': 4.294057148781622}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:45:29,844] Trial 87 finished with value: 0.36995170073680506 and parameters: {'num_leaves': 74, 'feature_fraction': 0.44454601517445363, 'bagging_fraction': 0.7585889446992067, 'bagging_freq': 14, 'learning_rate': 0.05759171214363273, 'lambda_l1': 5.188526947870651, 'lambda_l2': 19.736079033735717}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:45:48,799] Trial 88 finished with value: 0.36766830566384834 and parameters: {'num_leaves': 72, 'feature_fraction': 0.41470932794515003, 'bagging_fraction': 0.7611296152159448, 'bagging_freq': 16, 'learning_rate': 0.059893900349676885, 'lambda_l1': 8.642407124491761, 'lambda_l2': 0.1071411481689107}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:46:03,793] Trial 89 finished with value: 0.37034544429677757 and parameters: {'num_leaves': 85, 'feature_fraction': 0.4028943283456323, 'bagging_fraction': 0.7086483945604426, 'bagging_freq': 17, 'learning_rate': 0.05496062718401319, 'lambda_l1': 12.500084020291883, 'lambda_l2': 0.3082540109944886}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:46:18,533] Trial 90 finished with value: 0.36916197546894475 and parameters: {'num_leaves': 76, 'feature_fraction': 0.4203394749041313, 'bagging_fraction': 0.6835094375955706, 'bagging_freq': 16, 'learning_rate': 0.06327601146239233, 'lambda_l1': 6.021389467175296, 'lambda_l2': 2.228392127755862}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:46:40,416] Trial 91 finished with value: 0.37175390455660196 and parameters: {'num_leaves': 79, 'feature_fraction': 0.43168473786163375, 'bagging_fraction': 0.751581548406858, 'bagging_freq': 17, 'learning_rate': 0.04844505255439103, 'lambda_l1': 11.809483974351448, 'lambda_l2': 4.786073883505845}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:46:54,365] Trial 92 finished with value: 0.3696759834572342 and parameters: {'num_leaves': 76, 'feature_fraction': 0.4409734079082108, 'bagging_fraction': 0.7306436345775411, 'bagging_freq': 19, 'learning_rate': 0.052389596633092964, 'lambda_l1': 12.938998458610419, 'lambda_l2': 1.3879975153887225}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:47:17,666] Trial 93 finished with value: 0.37125943069863904 and parameters: {'num_leaves': 80, 'feature_fraction': 0.44988752798883247, 'bagging_fraction': 0.7162201673236801, 'bagging_freq': 18, 'learning_rate': 0.04262600676627243, 'lambda_l1': 17.099059035217874, 'lambda_l2': 11.377329900976811}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:47:31,664] Trial 94 finished with value: 0.369635192459878 and parameters: {'num_leaves': 78, 'feature_fraction': 0.42025987596408015, 'bagging_fraction': 0.6168483673596385, 'bagging_freq': 20, 'learning_rate': 0.0451427874625857, 'lambda_l1': 8.907696773680586, 'lambda_l2': 2.5158656783078133}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:47:52,571] Trial 95 finished with value: 0.3710973088751103 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4306000771695663, 'bagging_fraction': 0.7729428688748926, 'bagging_freq': 17, 'learning_rate': 0.05893106216325288, 'lambda_l1': 15.758377818148634, 'lambda_l2': 15.57641788020564}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:48:10,600] Trial 96 finished with value: 0.3672031801559501 and parameters: {'num_leaves': 81, 'feature_fraction': 0.4441261463181853, 'bagging_fraction': 0.6562906497366757, 'bagging_freq': 16, 'learning_rate': 0.056222486520097786, 'lambda_l1': 3.957149188839605, 'lambda_l2': 4.329815536277178}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:48:24,222] Trial 97 finished with value: 0.37153619742419874 and parameters: {'num_leaves': 50, 'feature_fraction': 0.39219036708328314, 'bagging_fraction': 0.5844075167055862, 'bagging_freq': 15, 'learning_rate': 0.05071976866352184, 'lambda_l1': 6.698268549642819, 'lambda_l2': 0.4471747836255568}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:48:42,702] Trial 98 finished with value: 0.37075470430006846 and parameters: {'num_leaves': 73, 'feature_fraction': 0.45583772023310726, 'bagging_fraction': 0.6428570601150991, 'bagging_freq': 17, 'learning_rate': 0.06105501329529031, 'lambda_l1': 10.019236709899857, 'lambda_l2': 8.922695246708596}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:49:04,450] Trial 99 finished with value: 0.3717516260841334 and parameters: {'num_leaves': 86, 'feature_fraction': 0.42597282313105644, 'bagging_fraction': 0.6781431645654787, 'bagging_freq': 18, 'learning_rate': 0.04195468111298241, 'lambda_l1': 12.749529115169192, 'lambda_l2': 0.7990815651201933}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:49:22,018] Trial 100 finished with value: 0.36637692100520525 and parameters: {'num_leaves': 75, 'feature_fraction': 0.38092079058135975, 'bagging_fraction': 0.7229141478551683, 'bagging_freq': 19, 'learning_rate': 0.06540624095679018, 'lambda_l1': 0.06687369259532666, 'lambda_l2': 20.700537652675216}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:49:39,969] Trial 101 finished with value: 0.3693786180823396 and parameters: {'num_leaves': 83, 'feature_fraction': 0.43400804650444774, 'bagging_fraction': 0.7736890864697037, 'bagging_freq': 18, 'learning_rate': 0.08753091425241454, 'lambda_l1': 16.179152803355237, 'lambda_l2': 3.5506297968207376}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:49:57,904] Trial 102 finished with value: 0.37290921931223486 and parameters: {'num_leaves': 84, 'feature_fraction': 0.3674008936026667, 'bagging_fraction': 0.7952645524763805, 'bagging_freq': 19, 'learning_rate': 0.05470644108648176, 'lambda_l1': 13.84415618232657, 'lambda_l2': 10.383766965386062}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:50:16,800] Trial 103 finished with value: 0.3697491040682863 and parameters: {'num_leaves': 84, 'feature_fraction': 0.35879247284866006, 'bagging_fraction': 0.8077859351549015, 'bagging_freq': 20, 'learning_rate': 0.05475220350498257, 'lambda_l1': 7.310429363566299, 'lambda_l2': 10.879479824715162}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:50:39,887] Trial 104 finished with value: 0.37370242058095576 and parameters: {'num_leaves': 79, 'feature_fraction': 0.365908060691557, 'bagging_fraction': 0.7425308541178337, 'bagging_freq': 13, 'learning_rate': 0.04692396956768709, 'lambda_l1': 19.984486044327678, 'lambda_l2': 15.241171547808412}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:50:58,196] Trial 105 finished with value: 0.37177203900123146 and parameters: {'num_leaves': 77, 'feature_fraction': 0.4177570016820935, 'bagging_fraction': 0.7451734381242632, 'bagging_freq': 10, 'learning_rate': 0.046291347601766536, 'lambda_l1': 19.952617511865846, 'lambda_l2': 20.435612942193725}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:51:17,927] Trial 106 finished with value: 0.36603445263297935 and parameters: {'num_leaves': 79, 'feature_fraction': 0.40212352575256094, 'bagging_fraction': 0.6972424254779592, 'bagging_freq': 12, 'learning_rate': 0.03940385377791843, 'lambda_l1': 9.703948801955226, 'lambda_l2': 0.21570393820670622}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:51:30,838] Trial 107 finished with value: 0.37149039037294374 and parameters: {'num_leaves': 81, 'feature_fraction': 0.40857005311862654, 'bagging_fraction': 0.6250865709974966, 'bagging_freq': 13, 'learning_rate': 0.04849036720568477, 'lambda_l1': 5.4900696467107, 'lambda_l2': 14.585688960328604}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:51:50,672] Trial 108 finished with value: 0.36952836383279397 and parameters: {'num_leaves': 78, 'feature_fraction': 0.449713487981094, 'bagging_fraction': 0.7018470940371737, 'bagging_freq': 16, 'learning_rate': 0.05233707236094043, 'lambda_l1': 0.9057976609533521, 'lambda_l2': 15.255043597952595}. Best is trial 51 with value: 0.37532893888651936.
# [I 2025-05-06 23:52:15,642] Trial 109 finished with value: 0.37632198960940616 and parameters: {'num_leaves': 80, 'feature_fraction': 0.4355113022651395, 'bagging_fraction': 0.6617167916698018, 'bagging_freq': 14, 'learning_rate': 0.049670672089416765, 'lambda_l1': 11.578931588449716, 'lambda_l2': 24.773815674040993}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:52:36,756] Trial 110 finished with value: 0.37159850323895166 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4382689395787582, 'bagging_fraction': 0.6674999087257911, 'bagging_freq': 13, 'learning_rate': 0.04362383749150171, 'lambda_l1': 7.919394182839624, 'lambda_l2': 24.171216446228026}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:52:58,005] Trial 111 finished with value: 0.372179673154532 and parameters: {'num_leaves': 80, 'feature_fraction': 0.42726544410889783, 'bagging_fraction': 0.6850220281549827, 'bagging_freq': 14, 'learning_rate': 0.047048473151967536, 'lambda_l1': 12.614241558016051, 'lambda_l2': 19.14365919530398}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:53:13,880] Trial 112 finished with value: 0.370662493177336 and parameters: {'num_leaves': 80, 'feature_fraction': 0.471434117352496, 'bagging_fraction': 0.6603950685491491, 'bagging_freq': 15, 'learning_rate': 0.04532342191283632, 'lambda_l1': 16.92016580566606, 'lambda_l2': 6.044485492861189}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:53:34,003] Trial 113 finished with value: 0.37425162004004314 and parameters: {'num_leaves': 79, 'feature_fraction': 0.4342341195594484, 'bagging_fraction': 0.7187354825828354, 'bagging_freq': 14, 'learning_rate': 0.04995514318806214, 'lambda_l1': 10.56923229390346, 'lambda_l2': 24.339298507057066}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:53:50,527] Trial 114 finished with value: 0.37168915842715977 and parameters: {'num_leaves': 82, 'feature_fraction': 0.4592692132547091, 'bagging_fraction': 0.5010518586736565, 'bagging_freq': 14, 'learning_rate': 0.04958705928583288, 'lambda_l1': 10.881273937998795, 'lambda_l2': 23.86068575641655}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:54:09,556] Trial 115 finished with value: 0.3710241444533729 and parameters: {'num_leaves': 79, 'feature_fraction': 0.4431329927120219, 'bagging_fraction': 0.5896702316649319, 'bagging_freq': 13, 'learning_rate': 0.05786602881154668, 'lambda_l1': 4.429106885420958, 'lambda_l2': 17.206663984697382}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:54:27,575] Trial 116 finished with value: 0.3686483393382028 and parameters: {'num_leaves': 87, 'feature_fraction': 0.42438608547067913, 'bagging_fraction': 0.7086059810489006, 'bagging_freq': 15, 'learning_rate': 0.05166578812087852, 'lambda_l1': 8.741487416546766, 'lambda_l2': 12.732824981403752}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:54:44,220] Trial 117 finished with value: 0.3738396410622361 and parameters: {'num_leaves': 81, 'feature_fraction': 0.33315888737717914, 'bagging_fraction': 0.6362950872304314, 'bagging_freq': 14, 'learning_rate': 0.029024468922676506, 'lambda_l1': 0.011987104994152025, 'lambda_l2': 19.28440421756392}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:55:13,004] Trial 118 finished with value: 0.37217703963698756 and parameters: {'num_leaves': 85, 'feature_fraction': 0.34327829187625913, 'bagging_fraction': 0.6394694299503939, 'bagging_freq': 12, 'learning_rate': 0.015452208297798508, 'lambda_l1': 0.009500196246706142, 'lambda_l2': 14.813582360393468}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:55:30,336] Trial 119 finished with value: 0.3731327395963842 and parameters: {'num_leaves': 81, 'feature_fraction': 0.3384784326820204, 'bagging_fraction': 0.6149723040854631, 'bagging_freq': 13, 'learning_rate': 0.03448835996724541, 'lambda_l1': 0.026797613707308123, 'lambda_l2': 21.082953309574734}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:55:56,004] Trial 120 finished with value: 0.3747774279024353 and parameters: {'num_leaves': 86, 'feature_fraction': 0.3354537497044747, 'bagging_fraction': 0.6509703368932326, 'bagging_freq': 11, 'learning_rate': 0.02415009955871061, 'lambda_l1': 0.0030387169312855694, 'lambda_l2': 9.018008317700739}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:56:18,829] Trial 121 finished with value: 0.3708031342027952 and parameters: {'num_leaves': 86, 'feature_fraction': 0.33876048544283094, 'bagging_fraction': 0.6307959212340456, 'bagging_freq': 8, 'learning_rate': 0.019920872917806823, 'lambda_l1': 0.005629892888789745, 'lambda_l2': 24.91739934367629}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:56:43,064] Trial 122 finished with value: 0.3687093679256206 and parameters: {'num_leaves': 83, 'feature_fraction': 0.33081768014082935, 'bagging_fraction': 0.65495458852901, 'bagging_freq': 14, 'learning_rate': 0.024893515710683177, 'lambda_l1': 0.0027109125086602053, 'lambda_l2': 11.879608881643096}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:57:00,038] Trial 123 finished with value: 0.3733133941842298 and parameters: {'num_leaves': 89, 'feature_fraction': 0.3288686147791138, 'bagging_fraction': 0.5676922079384897, 'bagging_freq': 11, 'learning_rate': 0.029548843017732886, 'lambda_l1': 0.0011819849680413709, 'lambda_l2': 17.310176146589544}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:57:23,793] Trial 124 finished with value: 0.372411838994304 and parameters: {'num_leaves': 84, 'feature_fraction': 0.34736018773336835, 'bagging_fraction': 0.6008969277957595, 'bagging_freq': 11, 'learning_rate': 0.027846895622630905, 'lambda_l1': 0.020616491983180007, 'lambda_l2': 9.09840517039745}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:57:44,762] Trial 125 finished with value: 0.37237170528463603 and parameters: {'num_leaves': 85, 'feature_fraction': 0.3232991550931748, 'bagging_fraction': 0.5505925363995936, 'bagging_freq': 11, 'learning_rate': 0.023446465727387233, 'lambda_l1': 0.0023998877535901723, 'lambda_l2': 19.782277763620115}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:58:27,239] Trial 126 finished with value: 0.3743700823628443 and parameters: {'num_leaves': 83, 'feature_fraction': 0.4368515686009869, 'bagging_fraction': 0.6731973873051766, 'bagging_freq': 10, 'learning_rate': 0.01196159301778454, 'lambda_l1': 0.014682422574390668, 'lambda_l2': 13.46126862211033}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:59:14,362] Trial 127 finished with value: 0.37165110725306466 and parameters: {'num_leaves': 83, 'feature_fraction': 0.43720229089258517, 'bagging_fraction': 0.6750356913916363, 'bagging_freq': 10, 'learning_rate': 0.007900259959290824, 'lambda_l1': 0.013326766361300807, 'lambda_l2': 8.162999026881508}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-06 23:59:50,912] Trial 128 finished with value: 0.3730320409575601 and parameters: {'num_leaves': 81, 'feature_fraction': 0.31078749519501864, 'bagging_fraction': 0.6905542144804978, 'bagging_freq': 12, 'learning_rate': 0.01368130443484805, 'lambda_l1': 0.004330461653945995, 'lambda_l2': 13.465853763131056}. Best is trial 109 with value: 0.37632198960940616.
# [I 2025-05-07 00:00:22,448] Trial 129 finished with value: 0.3683656031563497 and parameters: {'num_leaves': 82, 'feature_fraction': 0.45609267130079917, 'bagging_fraction': 0.3542364163651862, 'bagging_freq': 8, 'learning_rate': 0.017744386456009904, 'lambda_l1': 0.014719270608596275, 'lambda_l2': 16.199501448163687}. Best is trial 109 with value: 0.37632198960940616.
# ...
# [I 2025-05-07 01:12:57,678] Trial 307 finished with value: 0.37589538509279474 and parameters: {'num_leaves': 70, 'feature_fraction': 0.32693603550859474, 'bagging_fraction': 0.5590090310481047, 'bagging_freq': 19, 'learning_rate': 0.018649506405068995, 'lambda_l1': 19.654406432468548, 'lambda_l2': 0.055803039547868034}. Best is trial 152 with value: 0.3769656287006604.
# [I 2025-05-07 01:13:27,017] Trial 308 finished with value: 0.3763466244083043 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3230636420876312, 'bagging_fraction': 0.5492989399846497, 'bagging_freq': 19, 'learning_rate': 0.01778079215985794, 'lambda_l1': 19.5702980494958, 'lambda_l2': 0.0611198130634169}. Best is trial 152 with value: 0.3769656287006604.
# [I 2025-05-07 01:14:01,302] Trial 309 finished with value: 0.3758226992928781 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3252982100317061, 'bagging_fraction': 0.5496769558534118, 'bagging_freq': 19, 'learning_rate': 0.018094639118458142, 'lambda_l1': 19.333795020517318, 'lambda_l2': 0.05569598464423603}. Best is trial 152 with value: 0.3769656287006604.
# [I 2025-05-07 01:14:30,186] Trial 310 finished with value: 0.37620168610733007 and parameters: {'num_leaves': 71, 'feature_fraction': 0.31761414122458104, 'bagging_fraction': 0.5336958262751882, 'bagging_freq': 19, 'learning_rate': 0.01759020422189955, 'lambda_l1': 19.697129055972766, 'lambda_l2': 0.059329346462796556}. Best is trial 152 with value: 0.3769656287006604.
# [I 2025-05-07 01:14:56,537] Trial 311 finished with value: 0.37543128434431755 and parameters: {'num_leaves': 71, 'feature_fraction': 0.32389405576442004, 'bagging_fraction': 0.5328912159987949, 'bagging_freq': 19, 'learning_rate': 0.017649397305075924, 'lambda_l1': 16.69418751048922, 'lambda_l2': 0.05756165186612453}. Best is trial 152 with value: 0.3769656287006604.
# [I 2025-05-07 01:15:25,891] Trial 312 finished with value: 0.3795695325525016 and parameters: {'num_leaves': 71, 'feature_fraction': 0.31996887722138695, 'bagging_fraction': 0.5372418948817358, 'bagging_freq': 19, 'learning_rate': 0.01755632876200545, 'lambda_l1': 16.571562337276383, 'lambda_l2': 0.06314341983967049}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:15:48,373] Trial 313 finished with value: 0.3780331700561166 and parameters: {'num_leaves': 71, 'feature_fraction': 0.32139089268605203, 'bagging_fraction': 0.5443715881760666, 'bagging_freq': 19, 'learning_rate': 0.01827703567233135, 'lambda_l1': 17.32469109675606, 'lambda_l2': 0.03236988976141566}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:16:11,203] Trial 314 finished with value: 0.3734602492140138 and parameters: {'num_leaves': 71, 'feature_fraction': 0.32175737706535884, 'bagging_fraction': 0.8465372702163749, 'bagging_freq': 19, 'learning_rate': 0.017500942940380047, 'lambda_l1': 19.556077640975303, 'lambda_l2': 0.032442722503755704}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:16:31,896] Trial 315 finished with value: 0.3718454245635874 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3131567851103363, 'bagging_fraction': 0.5460490072030629, 'bagging_freq': 19, 'learning_rate': 0.012412265996930391, 'lambda_l1': 16.583327946544753, 'lambda_l2': 0.05323736673842526}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:16:56,961] Trial 316 finished with value: 0.3730666827790087 and parameters: {'num_leaves': 71, 'feature_fraction': 0.30438646173067063, 'bagging_fraction': 0.5306363222480498, 'bagging_freq': 19, 'learning_rate': 0.015629964438837504, 'lambda_l1': 16.25100756565022, 'lambda_l2': 0.0646948858940904}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:17:24,484] Trial 317 finished with value: 0.37579894327119073 and parameters: {'num_leaves': 70, 'feature_fraction': 0.31972532722611746, 'bagging_fraction': 0.5430006548968539, 'bagging_freq': 19, 'learning_rate': 0.01783096165158691, 'lambda_l1': 19.40672386788101, 'lambda_l2': 0.023416564616397906}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:17:52,783] Trial 318 finished with value: 0.3736053898557824 and parameters: {'num_leaves': 70, 'feature_fraction': 0.31871983072953214, 'bagging_fraction': 0.5481166801954711, 'bagging_freq': 19, 'learning_rate': 0.01755752917650006, 'lambda_l1': 13.734859115584687, 'lambda_l2': 0.027484893903458322}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:18:18,400] Trial 319 finished with value: 0.37141126151455794 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3239114932396538, 'bagging_fraction': 0.50061752935864, 'bagging_freq': 19, 'learning_rate': 0.014575050760884407, 'lambda_l1': 16.743748926021798, 'lambda_l2': 0.03506475126022549}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:18:46,188] Trial 320 finished with value: 0.3736078599298379 and parameters: {'num_leaves': 70, 'feature_fraction': 0.31045042210624185, 'bagging_fraction': 0.5224080038304985, 'bagging_freq': 23, 'learning_rate': 0.018382298903814782, 'lambda_l1': 12.178591568774122, 'lambda_l2': 0.03944613349692185}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:19:11,734] Trial 321 finished with value: 0.37553284743136334 and parameters: {'num_leaves': 72, 'feature_fraction': 0.31528514375954786, 'bagging_fraction': 0.5325256496770113, 'bagging_freq': 19, 'learning_rate': 0.016647658379216845, 'lambda_l1': 14.632488160687924, 'lambda_l2': 0.026517826010206386}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:19:36,219] Trial 322 finished with value: 0.37353717913251894 and parameters: {'num_leaves': 72, 'feature_fraction': 0.31889498011849343, 'bagging_fraction': 0.5364394591461172, 'bagging_freq': 19, 'learning_rate': 0.015877516597042146, 'lambda_l1': 17.075603755304193, 'lambda_l2': 0.026009941383665358}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:20:02,071] Trial 323 finished with value: 0.37438722138886316 and parameters: {'num_leaves': 69, 'feature_fraction': 0.30895591721348736, 'bagging_fraction': 0.47420367445629724, 'bagging_freq': 19, 'learning_rate': 0.018390279945216966, 'lambda_l1': 19.680334731361093, 'lambda_l2': 0.01960595424649031}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:20:22,010] Trial 324 finished with value: 0.37476993782005164 and parameters: {'num_leaves': 71, 'feature_fraction': 0.32450301647188795, 'bagging_fraction': 0.5524676877949833, 'bagging_freq': 19, 'learning_rate': 0.01731384006328785, 'lambda_l1': 15.890883247965247, 'lambda_l2': 0.02030863537545789}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:20:47,758] Trial 325 finished with value: 0.373197006288407 and parameters: {'num_leaves': 69, 'feature_fraction': 0.3196974643935162, 'bagging_fraction': 0.5073552773458346, 'bagging_freq': 19, 'learning_rate': 0.013449601281908993, 'lambda_l1': 14.22836777152696, 'lambda_l2': 0.0431389476535338}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:21:15,492] Trial 326 finished with value: 0.37733191203379013 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3272460551243099, 'bagging_fraction': 0.5271300167732602, 'bagging_freq': 25, 'learning_rate': 0.01947688154466285, 'lambda_l1': 19.908157099176183, 'lambda_l2': 0.05670404785057393}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:21:45,672] Trial 327 finished with value: 0.37706425510283365 and parameters: {'num_leaves': 73, 'feature_fraction': 0.31635580534460056, 'bagging_fraction': 0.525929927377003, 'bagging_freq': 19, 'learning_rate': 0.019629288202667097, 'lambda_l1': 19.476142102196214, 'lambda_l2': 0.0796174851189629}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:22:00,249] Trial 328 finished with value: 0.3698369007853432 and parameters: {'num_leaves': 72, 'feature_fraction': 0.31356403083768497, 'bagging_fraction': 0.5284553430457966, 'bagging_freq': 18, 'learning_rate': 0.08165947575912991, 'lambda_l1': 19.136933765534042, 'lambda_l2': 0.014678423456624373}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:22:25,362] Trial 329 finished with value: 0.37554877845215034 and parameters: {'num_leaves': 73, 'feature_fraction': 0.3044090282548905, 'bagging_fraction': 0.536662352204746, 'bagging_freq': 20, 'learning_rate': 0.019740700644118796, 'lambda_l1': 19.971958419980254, 'lambda_l2': 0.05205446262683127}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:22:52,529] Trial 330 finished with value: 0.3741420093155531 and parameters: {'num_leaves': 73, 'feature_fraction': 0.3026086553930783, 'bagging_fraction': 0.5372347383834487, 'bagging_freq': 25, 'learning_rate': 0.019867480071404025, 'lambda_l1': 18.33967751604815, 'lambda_l2': 0.05445594465620848}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:23:17,867] Trial 331 finished with value: 0.3775918539284757 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3085805740796781, 'bagging_fraction': 0.5234130947028174, 'bagging_freq': 20, 'learning_rate': 0.016406407286018884, 'lambda_l1': 19.486089831578884, 'lambda_l2': 0.044501209453918354}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:23:38,359] Trial 332 finished with value: 0.36367032961467954 and parameters: {'num_leaves': 73, 'feature_fraction': 0.30540160202690875, 'bagging_fraction': 0.5211808662845232, 'bagging_freq': 24, 'learning_rate': 0.012341482326052047, 'lambda_l1': 19.69368821723243, 'lambda_l2': 0.04432141318725424}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:24:03,891] Trial 333 finished with value: 0.3742698709879203 and parameters: {'num_leaves': 74, 'feature_fraction': 0.3086993215363601, 'bagging_fraction': 0.5313119179365967, 'bagging_freq': 20, 'learning_rate': 0.014910429660913636, 'lambda_l1': 19.7531734006356, 'lambda_l2': 0.0571008615327259}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:24:33,050] Trial 334 finished with value: 0.37358631050924795 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3181601897990349, 'bagging_fraction': 0.5473128482263024, 'bagging_freq': 20, 'learning_rate': 0.016211609840420364, 'lambda_l1': 14.23362644188344, 'lambda_l2': 0.024394722353704632}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:24:54,312] Trial 335 finished with value: 0.3729694011733363 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3139294616474603, 'bagging_fraction': 0.5248218287412432, 'bagging_freq': 20, 'learning_rate': 0.016718139153268096, 'lambda_l1': 14.843706396353177, 'lambda_l2': 0.034805988560664754}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:25:21,704] Trial 336 finished with value: 0.37495959082463937 and parameters: {'num_leaves': 70, 'feature_fraction': 0.30770669325047845, 'bagging_fraction': 0.5085420867102055, 'bagging_freq': 23, 'learning_rate': 0.01920135571867885, 'lambda_l1': 19.931127871195788, 'lambda_l2': 0.049511400580795964}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:25:44,969] Trial 337 finished with value: 0.3776318092000044 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3213604328748137, 'bagging_fraction': 0.5416808037070172, 'bagging_freq': 20, 'learning_rate': 0.020400694688207682, 'lambda_l1': 11.301622338125616, 'lambda_l2': 0.07493376850261091}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:26:05,822] Trial 338 finished with value: 0.3726600759377675 and parameters: {'num_leaves': 74, 'feature_fraction': 0.3155387035086381, 'bagging_fraction': 0.5589618605818397, 'bagging_freq': 20, 'learning_rate': 0.020955010464606606, 'lambda_l1': 10.837594517631711, 'lambda_l2': 0.07786810393305367}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:26:22,913] Trial 339 finished with value: 0.3752102942180935 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3016172243510589, 'bagging_fraction': 0.5430599228552385, 'bagging_freq': 20, 'learning_rate': 0.020446584561620056, 'lambda_l1': 12.642857203879593, 'lambda_l2': 0.00943778614637328}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:26:39,749] Trial 340 finished with value: 0.370974322907789 and parameters: {'num_leaves': 71, 'feature_fraction': 0.3189546486174846, 'bagging_fraction': 0.5565568010425674, 'bagging_freq': 19, 'learning_rate': 0.0682437642408869, 'lambda_l1': 14.156713399340928, 'lambda_l2': 0.0720234126215771}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:27:02,000] Trial 341 finished with value: 0.37146901659966874 and parameters: {'num_leaves': 73, 'feature_fraction': 0.32708211851981084, 'bagging_fraction': 0.5451332884697582, 'bagging_freq': 19, 'learning_rate': 0.01939709787797416, 'lambda_l1': 9.058050434142038, 'lambda_l2': 0.035651671737501604}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:27:27,147] Trial 342 finished with value: 0.3724844340449346 and parameters: {'num_leaves': 72, 'feature_fraction': 0.310030852148503, 'bagging_fraction': 0.521184637690358, 'bagging_freq': 20, 'learning_rate': 0.015228941897954274, 'lambda_l1': 11.506858796313223, 'lambda_l2': 0.04900150086601077}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:27:55,464] Trial 343 finished with value: 0.37019510744133266 and parameters: {'num_leaves': 70, 'feature_fraction': 0.32222946607732295, 'bagging_fraction': 0.5339612649605596, 'bagging_freq': 19, 'learning_rate': 0.009554587777755225, 'lambda_l1': 16.389762511214148, 'lambda_l2': 0.0864096273977488}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:28:28,585] Trial 344 finished with value: 0.3738259491152545 and parameters: {'num_leaves': 68, 'feature_fraction': 0.327918108491339, 'bagging_fraction': 0.5559896977832975, 'bagging_freq': 20, 'learning_rate': 0.013364865841697878, 'lambda_l1': 19.95611231649413, 'lambda_l2': 0.0660173818062347}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:28:50,902] Trial 345 finished with value: 0.3742653083550148 and parameters: {'num_leaves': 72, 'feature_fraction': 0.3130322315738382, 'bagging_fraction': 0.5119826536262976, 'bagging_freq': 20, 'learning_rate': 0.01708250136907761, 'lambda_l1': 14.281774584879685, 'lambda_l2': 0.02905231099342407}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:29:21,368] Trial 346 finished with value: 0.37734729447158266 and parameters: {'num_leaves': 75, 'feature_fraction': 0.31765915602635403, 'bagging_fraction': 0.542400835455075, 'bagging_freq': 19, 'learning_rate': 0.020634301124722705, 'lambda_l1': 19.99233775565518, 'lambda_l2': 0.03760190063130653}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:29:43,003] Trial 347 finished with value: 0.3722398971750275 and parameters: {'num_leaves': 75, 'feature_fraction': 0.3178613538398051, 'bagging_fraction': 0.5442936554337899, 'bagging_freq': 18, 'learning_rate': 0.020529911583384984, 'lambda_l1': 19.687152576529403, 'lambda_l2': 0.039940658541322276}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:30:11,605] Trial 348 finished with value: 0.3757900325348408 and parameters: {'num_leaves': 73, 'feature_fraction': 0.3080156290554319, 'bagging_fraction': 0.523272799381031, 'bagging_freq': 19, 'learning_rate': 0.018469629989978337, 'lambda_l1': 16.114552716991785, 'lambda_l2': 0.021152687177902002}. Best is trial 312 with value: 0.3795695325525016.
# [I 2025-05-07 01:30:31,994] Trial 349 finished with value: 0.37487231424752665 and parameters: {'num_leaves': 73, 'feature_fraction': 0.30096398821702564, 'bagging_fraction': 0.5052870510361336, 'bagging_freq': 19, 'learning_rate': 0.018687324913643603, 'lambda_l1': 19.97961832585349, 'lambda_l2': 0.05682950964949791}. Best is trial 312 with value: 0.3795695325525016.

# %%
top_trials = sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]  # For minimization
# or reverse=True if you're maximizing

# Print parameters of top trials
for i, trial in enumerate(top_trials, 1):
    print(f"Top {i}:")
    print(f"  Value: {trial.value}")
    print(f"  Params: {trial.params}")
# Out:
# Top 1:
#   Value: 0.3795695325525016
#   Params: {'num_leaves': 71, 'feature_fraction': 0.31996887722138695, 'bagging_fraction': 0.5372418948817358, 'bagging_freq': 19, 'learning_rate': 0.01755632876200545, 'lambda_l1': 16.571562337276383, 'lambda_l2': 0.06314341983967049}
# Top 2:
#   Value: 0.3780331700561166
#   Params: {'num_leaves': 71, 'feature_fraction': 0.32139089268605203, 'bagging_fraction': 0.5443715881760666, 'bagging_freq': 19, 'learning_rate': 0.01827703567233135, 'lambda_l1': 17.32469109675606, 'lambda_l2': 0.03236988976141566}
# Top 3:
#   Value: 0.3776318092000044
#   Params: {'num_leaves': 72, 'feature_fraction': 0.3213604328748137, 'bagging_fraction': 0.5416808037070172, 'bagging_freq': 20, 'learning_rate': 0.020400694688207682, 'lambda_l1': 11.301622338125616, 'lambda_l2': 0.07493376850261091}
# Top 4:
#   Value: 0.3775918539284757
#   Params: {'num_leaves': 72, 'feature_fraction': 0.3085805740796781, 'bagging_fraction': 0.5234130947028174, 'bagging_freq': 20, 'learning_rate': 0.016406407286018884, 'lambda_l1': 19.486089831578884, 'lambda_l2': 0.044501209453918354}
# Top 5:
#   Value: 0.37734729447158266
#   Params: {'num_leaves': 75, 'feature_fraction': 0.31765915602635403, 'bagging_fraction': 0.542400835455075, 'bagging_freq': 19, 'learning_rate': 0.020634301124722705, 'lambda_l1': 19.99233775565518, 'lambda_l2': 0.03760190063130653}

# %%
# difference_min, info_min = study.best_trial.user_attrs['difference_min'], study.best_trial.user_attrs['info_min']
difference_min, info_min = 0.05, 0.03

presence_info_df_3 = presence_info_df_3[(np.abs(presence_info_df_3['difference']) > difference_min) & (presence_info_df_3['info'] > info_min)]
presence_info_df = presence_info_df_3

updated_train_df = add_presence_columns(train_df, presence_info_df)
updated_test_df = add_presence_columns(test_df, presence_info_df)

present_cols = [col for col in updated_train_df.columns if col.endswith('_present')]
# print(updated_train_df[non_present_cols].info())


high_dim_cat_cols_to_drop = ['claim_date.day', 'claim_date.dayofweek', 'claim_date.weekofyear', 'claim_date.month', 'zero_payout']
updated_train_df.drop(columns = high_dim_cat_cols_to_drop, inplace=True)
updated_test_df.drop(columns = high_dim_cat_cols_to_drop, inplace=True)

# Step 1: Fit on training data
onehot, scaler, cat_cols, num_cols = fit_regular_transformer(updated_train_df)

# Step 2: Transform training set itself
X_train_regular = transform_regular_set(updated_train_df, onehot, scaler, cat_cols, num_cols)

# Step 3: Transform test set (call the same function on test_df)
X_test_regular = transform_regular_set(test_df, onehot, scaler, cat_cols, num_cols)

# present_cols = []
# Combine for train
updated_train_final = pd.concat([X_train_regular, updated_train_df[present_cols]], axis=1)

# Combine for test
updated_test_final = pd.concat([X_test_regular, updated_test_df[present_cols]], axis=1)

# %%
# Paths
import json
output_dir = '../Records/lgb_temp'
train_csv_path = os.path.join(output_dir, 'train_2025.csv')
test_csv_path = os.path.join(output_dir, 'test_2025.csv')
param_json_path = os.path.join(output_dir, 'param_lgb_temp.json')

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Save DataFrames
train_df.to_csv(train_csv_path, index=False)
print(f"Saved train DataFrame to {train_csv_path}")

test_df.to_csv(test_csv_path, index=False)
print(f"Saved test DataFrame to {test_csv_path}")

# Save best_params as JSON
best_threshold = study.best_trial.user_attrs['mean_threshold']
best_params = study.best_params
best_params.update({'mean_threshold': float(best_threshold)})
with open(param_json_path, 'w') as f:
    json.dump(best_params, f, indent=4)
print(f"Saved best parameters to {param_json_path}")
# Out:
# Saved train DataFrame to ../Records/lgb_temp\train_2025.csv
# Saved test DataFrame to ../Records/lgb_temp\test_2025.csv
# Saved best parameters to ../Records/lgb_temp\param_lgb_temp.json

# %%
# Split train into final train and validation sets
X_train_final, X_val_final, y_train_final, y_val_final = train_test_split(
    updated_train_final, target, test_size=0.01, stratify=target, random_state=42
)

# Create LightGBM datasets
lgb_train_final = lgb.Dataset(X_train_final, y_train_final)
lgb_val_final = lgb.Dataset(X_val_final, y_val_final, reference=lgb_train_final)

# Ensure best_params includes all needed keys
best_params.update({
    'objective': 'binary',
    'metric': ['auc'],
    'is_unbalance': True,
    'boosting': 'gbdt',
    'device': 'gpu', 
    'verbose': -1,
    'seed': 69
})

# Train with early stopping
final_model = lgb.train(
    best_params,
    lgb_train_final,
    num_boost_round=5000,
    valid_sets=[lgb_val_final],
    callbacks=[
        lgb.early_stopping(stopping_rounds=100),
        lgb.log_evaluation(period=100)  # Optional: adjust or silence logging
    ]
)

# Predict on test set
probs_test = final_model.predict(updated_test_final, num_iteration=final_model.best_iteration)
# Out:
# Training until validation scores don't improve for 100 rounds
# [100]	valid_0's auc: 0.694314
# [200]	valid_0's auc: 0.700423
# [300]	valid_0's auc: 0.703947
# [400]	valid_0's auc: 0.708647
# [500]	valid_0's auc: 0.709117
# [600]	valid_0's auc: 0.708647
# Early stopping, best iteration is:
# [536]	valid_0's auc: 0.711936

# %%
timestamp = datetime.now().strftime('%m%d_%H%M')

final_preds = (probs_test > best_threshold).astype(int)

submission = pd.DataFrame({
    'claim_number': test_id,
    'fraud': final_preds
})

submission.to_csv(f'../Submit/submission_lgb.csv', index=False)
