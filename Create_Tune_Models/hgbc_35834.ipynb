# %%
import numpy as np 
import pandas as pd 
import sys
import os
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.decomposition import PCA
import matplotlib.pylab as plt
import warnings
from datetime import datetime
import itertools
from scipy import stats

warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize']=10,20

# Add the grandparent directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../')))
from Utils import FE_helper as FE

# %%
# 2. Load the data
train_df = pd.read_csv('../Original_Data/train_2025.csv') 
test_df = pd.read_csv('../Original_Data/test_2025.csv')

train_df = FE.add_features(train_df)
test_df = FE.add_features(test_df)

test_id = test_df['claim_number']
train_id = train_df['claim_number']
target = train_df['fraud']

ignore_var = ['claim_date.is_weekend', 'claim_date.near_holiday', 'fraud']
train_df = FE.drop_ignored_columns(train_df, ignore_var)
test_df = FE.drop_ignored_columns(test_df, ignore_var)

# %%
def add_presence_columns(train_df, presence_info_df, verbose = False):
    """
    For each combo in presence_info_df, create a presence feature on train_df.
    
    Parameters:
    - train_df (pd.DataFrame): The training dataset.
    - presence_info_df (pd.DataFrame): DataFrame containing 'feature' column
      with names like 'feature1__feature2__feature3_present'.
    
    Returns:
    - pd.DataFrame: train_df with new presence columns added.
    """
    df_out = train_df.copy()
    
    for combo_str in presence_info_df['feature']:
        # Extract base combo name (strip trailing '_present')
        if combo_str.endswith('_present'):
            combo_base = combo_str[:-8]
        else:
            combo_base = combo_str
        
        # Split by '__' to get the individual features
        combo_features = combo_base.split('__')
        new_col_name = combo_base + '_present'  # keep consistent
        if verbose:
            print(f"Processing combo: {combo_features}")
        
        # Build tuple of feature values per row
        combo_tuples = train_df[combo_features].apply(tuple, axis=1)
        
        # Count how many times each tuple appears
        counts = combo_tuples.map(combo_tuples.value_counts())
        
        # Presence = appears more than once in the dataset
        df_out[new_col_name] = (counts > 1).astype(int)
    
    return df_out


def fit_presence_pca(train_df, present_cols, n_components=None, scale=True):
    """
    Fits PCA on presence feature columns in the training set.
    
    Parameters:
    - train_df (pd.DataFrame): Training dataset.
    - present_cols (list): List of column names for presence features.
    - n_components (int or None): Number of PCA components. If None, keep all.
    - scale (bool): Whether to standardize columns before PCA.
    
    Returns:
    - pca (PCA object): Fitted PCA object.
    - X_train_pca (np.ndarray): Transformed training set (PCA scores).
    - scaler (StandardScaler object or None): Fitted scaler if used, else None.
    """
    X = train_df[present_cols].values

    # Optionally scale features
    scaler = None
    if scale:
        scaler = StandardScaler()
        X = scaler.fit_transform(X)

    # Fit PCA
    pca = PCA(n_components=n_components, random_state=42)
    X_train_pca = pca.fit_transform(X)

    print(f"PCA fitted. Explained variance (first 10 components): {pca.explained_variance_ratio_[:10]}")
    return pca, X_train_pca, scaler



def fit_regular_transformer(train_df, presence_suffix='_present'):
    # Identify regular columns
    regular_cols = [col for col in train_df.columns if not col.endswith(presence_suffix)]
    
    # Split regular into categorical and numerical
    categorical_cols = train_df[regular_cols].select_dtypes(include=['object', 'category']).columns.tolist()
    numerical_cols = train_df[regular_cols].select_dtypes(include=['number']).columns.tolist()
    if 'claim_number' in numerical_cols:
        numerical_cols.remove('claim_number')
    
    # Initialize transformers
    onehot = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
    scaler = StandardScaler()
    
    # Fit transformers
    onehot.fit(train_df[categorical_cols])
    scaler.fit(train_df[numerical_cols])
    
    # print(f"Fitted on {len(categorical_cols)} categorical and {len(numerical_cols)} numerical columns.")
    
    return onehot, scaler, categorical_cols, numerical_cols

def transform_regular_set(df, onehot, scaler, categorical_cols, numerical_cols):
    # Transform categorical
    cat_transformed = onehot.transform(df[categorical_cols])
    cat_df = pd.DataFrame(cat_transformed, columns=onehot.get_feature_names_out(categorical_cols), index=df.index)
    
    # Transform numerical
    num_transformed = scaler.transform(df[numerical_cols])
    num_df = pd.DataFrame(num_transformed, columns=numerical_cols, index=df.index)
    
    # Combine transformed parts
    transformed_df = pd.concat([num_df, cat_df], axis=1)
    
    # print(f"Transformed set shape: {transformed_df.shape}")
    return transformed_df

# %%
def objective(trial, train_df, presence_info_df, target, kfoldcv=5, drop=[]):
    # Feature selection thresholds
    difference_min = 0.05
    info_min = 0.03
    presence_info_df = presence_info_df[
        (np.abs(presence_info_df['difference']) > difference_min) &
        (presence_info_df['info'] > info_min)
    ]

    # Add presence features
    updated_train_df = add_presence_columns(train_df, presence_info_df)
    present_cols = [col for col in updated_train_df.columns if col.endswith('_present')]

    # Drop high-cardinality categorical columns
    high_dim_cat_cols_to_drop = ['claim_date.day', 'claim_date.dayofweek', 'claim_date.weekofyear',
                                 'claim_date.month']
    updated_train_df.drop(columns=high_dim_cat_cols_to_drop, inplace=True)

    # Transform regular features
    onehot, scaler, cat_cols, num_cols = fit_regular_transformer(updated_train_df)
    X_train_regular = transform_regular_set(updated_train_df, onehot, scaler, cat_cols, num_cols)

    # Combine with presence features
    full_train_df = pd.concat([X_train_regular, updated_train_df[present_cols]], axis=1)

    # Define hyperparameter space for HGBC
    params = {
        'max_iter': 2000,
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.1),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 20, 90),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 10, 50),
        'l2_regularization': trial.suggest_float('l2_regularization', 1e-3, 25.0, log=True),
        'early_stopping': True,
        'validation_fraction': 0.1,
        'random_state': 69,
        'verbose': 0
    }

    skf = StratifiedKFold(n_splits=kfoldcv, shuffle=True, random_state=42)
    best_thresholds = []
    f1_scores = []

    for train_idx, val_idx in skf.split(full_train_df, target):
        X_train = full_train_df.iloc[train_idx].drop(columns=drop, errors='ignore')
        X_val = full_train_df.iloc[val_idx].drop(columns=drop, errors='ignore')
        y_train = target.iloc[train_idx]
        y_val = target.iloc[val_idx]

        # Instantiate and train the model
        model = HistGradientBoostingClassifier(**params)
        model.fit(X_train, y_train)

        # Predict + threshold tuning
        probs = model.predict_proba(X_val)[:, 1]
        thresholds = np.linspace(0.1, 0.9, 50)
        f1s = [f1_score(y_val, probs > t) for t in thresholds]

        best_f1 = max(f1s)
        best_threshold = thresholds[np.argmax(f1s)]

        f1_scores.append(best_f1)
        best_thresholds.append(best_threshold)

    mean_f1 = np.mean(f1_scores)
    mean_threshold = np.mean(best_thresholds)

    trial.set_user_attr('mean_threshold', mean_threshold)
    trial.set_user_attr('f1_per_fold', f1_scores)

    return mean_f1

# %%
presence_info_df_3 = pd.read_csv('logs/subset_info_3.csv')
# Run Optuna
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='maximize', pruner=pruner)
study.optimize(lambda trial: objective(trial, train_df, presence_info_df_3, target, kfoldcv= 5),
                n_trials=350)

best_f1 = study.best_value
# Out:
# [I 2025-05-07 10:29:39,412] A new study created in memory with name: no-name-1bbb7d41-7a08-47ed-996f-72338ab747f9
# [I 2025-05-07 10:29:48,423] Trial 0 finished with value: 0.3619930822892148 and parameters: {'learning_rate': 0.029267251208555764, 'max_leaf_nodes': 77, 'min_samples_leaf': 50, 'l2_regularization': 6.841872624812442}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:29:54,103] Trial 1 finished with value: 0.35807020759583996 and parameters: {'learning_rate': 0.08955473704257991, 'max_leaf_nodes': 54, 'min_samples_leaf': 24, 'l2_regularization': 4.748984380510635}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:29:59,351] Trial 2 finished with value: 0.3606258850497981 and parameters: {'learning_rate': 0.06212496879082172, 'max_leaf_nodes': 36, 'min_samples_leaf': 18, 'l2_regularization': 0.001497202596797329}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:30:04,742] Trial 3 finished with value: 0.35919746441001665 and parameters: {'learning_rate': 0.06655121537319036, 'max_leaf_nodes': 45, 'min_samples_leaf': 36, 'l2_regularization': 0.010342719746977603}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:30:11,341] Trial 4 finished with value: 0.36013229165398036 and parameters: {'learning_rate': 0.030098036188947505, 'max_leaf_nodes': 74, 'min_samples_leaf': 39, 'l2_regularization': 0.0021752173201983896}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:30:22,558] Trial 5 finished with value: 0.3599795706896048 and parameters: {'learning_rate': 0.010464374589764083, 'max_leaf_nodes': 75, 'min_samples_leaf': 36, 'l2_regularization': 0.03840045441797146}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:30:27,431] Trial 6 finished with value: 0.3583315244092492 and parameters: {'learning_rate': 0.07086974926782041, 'max_leaf_nodes': 47, 'min_samples_leaf': 19, 'l2_regularization': 0.005411859643410228}. Best is trial 0 with value: 0.3619930822892148.
# [I 2025-05-07 10:30:34,528] Trial 7 finished with value: 0.36291780227087866 and parameters: {'learning_rate': 0.03585876312670623, 'max_leaf_nodes': 87, 'min_samples_leaf': 37, 'l2_regularization': 2.0698333238386413}. Best is trial 7 with value: 0.36291780227087866.
# [I 2025-05-07 10:30:41,185] Trial 8 finished with value: 0.36001175212863146 and parameters: {'learning_rate': 0.03211687442860159, 'max_leaf_nodes': 50, 'min_samples_leaf': 34, 'l2_regularization': 0.0015991412273235498}. Best is trial 7 with value: 0.36291780227087866.
# [I 2025-05-07 10:30:47,219] Trial 9 finished with value: 0.3652119989464215 and parameters: {'learning_rate': 0.02764511864888324, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'l2_regularization': 1.7510310018037256}. Best is trial 9 with value: 0.3652119989464215.
# [I 2025-05-07 10:30:59,413] Trial 10 finished with value: 0.3613222240924186 and parameters: {'learning_rate': 0.005555768430360278, 'max_leaf_nodes': 23, 'min_samples_leaf': 11, 'l2_regularization': 0.3864403801474114}. Best is trial 9 with value: 0.3652119989464215.
# [I 2025-05-07 10:31:06,069] Trial 11 finished with value: 0.3584418354732648 and parameters: {'learning_rate': 0.04122403717938434, 'max_leaf_nodes': 90, 'min_samples_leaf': 47, 'l2_regularization': 1.0168661938683976}. Best is trial 9 with value: 0.3652119989464215.
# [I 2025-05-07 10:31:11,890] Trial 12 finished with value: 0.36896567361856175 and parameters: {'learning_rate': 0.04550755258173238, 'max_leaf_nodes': 20, 'min_samples_leaf': 27, 'l2_regularization': 23.590293691879033}. Best is trial 12 with value: 0.36896567361856175.
# [I 2025-05-07 10:31:18,279] Trial 13 finished with value: 0.3703052760724698 and parameters: {'learning_rate': 0.05359139412910621, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'l2_regularization': 20.82757631240789}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:24,670] Trial 14 finished with value: 0.36490781216738066 and parameters: {'learning_rate': 0.05151877030360122, 'max_leaf_nodes': 32, 'min_samples_leaf': 29, 'l2_regularization': 24.68619991714201}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:30,597] Trial 15 finished with value: 0.3665784999734686 and parameters: {'learning_rate': 0.0818290074953325, 'max_leaf_nodes': 34, 'min_samples_leaf': 17, 'l2_regularization': 23.502842842471676}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:35,939] Trial 16 finished with value: 0.36129310972163353 and parameters: {'learning_rate': 0.05104914116419424, 'max_leaf_nodes': 27, 'min_samples_leaf': 25, 'l2_regularization': 0.10417720814042261}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:43,502] Trial 17 finished with value: 0.36176115094820266 and parameters: {'learning_rate': 0.045203056168227604, 'max_leaf_nodes': 63, 'min_samples_leaf': 14, 'l2_regularization': 6.278645831576765}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:49,678] Trial 18 finished with value: 0.360867174529501 and parameters: {'learning_rate': 0.060377129489468336, 'max_leaf_nodes': 39, 'min_samples_leaf': 42, 'l2_regularization': 0.4198646908438784}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:31:58,950] Trial 19 finished with value: 0.3661696971237066 and parameters: {'learning_rate': 0.017684144016136816, 'max_leaf_nodes': 28, 'min_samples_leaf': 24, 'l2_regularization': 11.411780743681668}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:04,681] Trial 20 finished with value: 0.35289488249136114 and parameters: {'learning_rate': 0.07593584676375323, 'max_leaf_nodes': 65, 'min_samples_leaf': 28, 'l2_regularization': 0.05270952935749377}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:10,265] Trial 21 finished with value: 0.3671178579838145 and parameters: {'learning_rate': 0.09658133562537902, 'max_leaf_nodes': 22, 'min_samples_leaf': 16, 'l2_regularization': 24.753588436596274}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:15,665] Trial 22 finished with value: 0.36788482896666047 and parameters: {'learning_rate': 0.09412356384274992, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 15.256383901015884}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:21,368] Trial 23 finished with value: 0.36001463580347604 and parameters: {'learning_rate': 0.08341154728929276, 'max_leaf_nodes': 41, 'min_samples_leaf': 13, 'l2_regularization': 2.7824763032119995}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:26,700] Trial 24 finished with value: 0.36431654302023764 and parameters: {'learning_rate': 0.09752152893647942, 'max_leaf_nodes': 28, 'min_samples_leaf': 21, 'l2_regularization': 10.729086886444898}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:31,988] Trial 25 finished with value: 0.36292877098766835 and parameters: {'learning_rate': 0.058407357474162785, 'max_leaf_nodes': 20, 'min_samples_leaf': 21, 'l2_regularization': 0.6835477716742201}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:38,296] Trial 26 finished with value: 0.36674850684636745 and parameters: {'learning_rate': 0.04654598425214744, 'max_leaf_nodes': 30, 'min_samples_leaf': 10, 'l2_regularization': 11.525117856564119}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:45,459] Trial 27 finished with value: 0.3652021056362151 and parameters: {'learning_rate': 0.020611636783700114, 'max_leaf_nodes': 25, 'min_samples_leaf': 32, 'l2_regularization': 4.26727266913718}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:50,897] Trial 28 finished with value: 0.3633133920389059 and parameters: {'learning_rate': 0.07280053383662657, 'max_leaf_nodes': 37, 'min_samples_leaf': 15, 'l2_regularization': 11.31757072717189}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:32:57,052] Trial 29 finished with value: 0.36113678350841966 and parameters: {'learning_rate': 0.03884350156991846, 'max_leaf_nodes': 42, 'min_samples_leaf': 13, 'l2_regularization': 1.1233133782050122}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:03,074] Trial 30 finished with value: 0.3591567913563334 and parameters: {'learning_rate': 0.05733320245454848, 'max_leaf_nodes': 63, 'min_samples_leaf': 27, 'l2_regularization': 3.370265641876244}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:08,152] Trial 31 finished with value: 0.36745740380637076 and parameters: {'learning_rate': 0.08894585344338696, 'max_leaf_nodes': 23, 'min_samples_leaf': 16, 'l2_regularization': 20.844706896126684}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:13,072] Trial 32 finished with value: 0.3664958515902569 and parameters: {'learning_rate': 0.09079010108413475, 'max_leaf_nodes': 24, 'min_samples_leaf': 19, 'l2_regularization': 7.106237622032506}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:18,234] Trial 33 finished with value: 0.36284401651480896 and parameters: {'learning_rate': 0.08650319617321321, 'max_leaf_nodes': 32, 'min_samples_leaf': 21, 'l2_regularization': 15.255020240476862}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:22,984] Trial 34 finished with value: 0.36570220561402256 and parameters: {'learning_rate': 0.09203280590658491, 'max_leaf_nodes': 20, 'min_samples_leaf': 12, 'l2_regularization': 6.127535381251848}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:28,043] Trial 35 finished with value: 0.36729719064664534 and parameters: {'learning_rate': 0.07701497774594152, 'max_leaf_nodes': 24, 'min_samples_leaf': 16, 'l2_regularization': 16.884003706756783}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:33,238] Trial 36 finished with value: 0.36346948996027156 and parameters: {'learning_rate': 0.09916334817269176, 'max_leaf_nodes': 56, 'min_samples_leaf': 23, 'l2_regularization': 7.300507885433582}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:38,479] Trial 37 finished with value: 0.3656259367953615 and parameters: {'learning_rate': 0.06673757422290003, 'max_leaf_nodes': 35, 'min_samples_leaf': 32, 'l2_regularization': 4.473218482972491}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:43,875] Trial 38 finished with value: 0.36824237777636004 and parameters: {'learning_rate': 0.06590533855693183, 'max_leaf_nodes': 28, 'min_samples_leaf': 14, 'l2_regularization': 16.344112356129948}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:49,000] Trial 39 finished with value: 0.3626874855453696 and parameters: {'learning_rate': 0.06412319125120464, 'max_leaf_nodes': 28, 'min_samples_leaf': 18, 'l2_regularization': 1.8690674069672464}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:54,092] Trial 40 finished with value: 0.36119167293242416 and parameters: {'learning_rate': 0.053837455641391724, 'max_leaf_nodes': 31, 'min_samples_leaf': 40, 'l2_regularization': 0.00955142169733997}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:33:58,987] Trial 41 finished with value: 0.3664774041353356 and parameters: {'learning_rate': 0.07971448765307905, 'max_leaf_nodes': 25, 'min_samples_leaf': 14, 'l2_regularization': 16.689326780681025}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:04,075] Trial 42 finished with value: 0.3697236785414522 and parameters: {'learning_rate': 0.06906147978163182, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 8.736048373495631}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:09,097] Trial 43 finished with value: 0.367042526331594 and parameters: {'learning_rate': 0.06825395241608725, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'l2_regularization': 9.518479138346478}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:14,495] Trial 44 finished with value: 0.3643856989257341 and parameters: {'learning_rate': 0.04545907120643579, 'max_leaf_nodes': 26, 'min_samples_leaf': 12, 'l2_regularization': 2.9147822549126743}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:19,740] Trial 45 finished with value: 0.370013495000856 and parameters: {'learning_rate': 0.06270395492984171, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 14.348375273105573}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:25,149] Trial 46 finished with value: 0.3635092025121759 and parameters: {'learning_rate': 0.06313716023789556, 'max_leaf_nodes': 45, 'min_samples_leaf': 26, 'l2_regularization': 5.327606747119515}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:30,326] Trial 47 finished with value: 0.3637503431623725 and parameters: {'learning_rate': 0.055106484493584254, 'max_leaf_nodes': 30, 'min_samples_leaf': 19, 'l2_regularization': 0.1676387934935403}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:35,957] Trial 48 finished with value: 0.36148583752853036 and parameters: {'learning_rate': 0.07106900375429008, 'max_leaf_nodes': 34, 'min_samples_leaf': 23, 'l2_regularization': 8.423851130022642}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:41,715] Trial 49 finished with value: 0.36632630894832824 and parameters: {'learning_rate': 0.04924154076625946, 'max_leaf_nodes': 23, 'min_samples_leaf': 31, 'l2_regularization': 23.659955633025312}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:46,623] Trial 50 finished with value: 0.3614377462851972 and parameters: {'learning_rate': 0.0609263595782821, 'max_leaf_nodes': 27, 'min_samples_leaf': 49, 'l2_regularization': 1.2549030965193975}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:51,735] Trial 51 finished with value: 0.36950788103470716 and parameters: {'learning_rate': 0.06759796956729494, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 15.758374193696373}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:34:56,797] Trial 52 finished with value: 0.36593163627336356 and parameters: {'learning_rate': 0.06792942285052228, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 15.177758452586563}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:01,703] Trial 53 finished with value: 0.366217638646136 and parameters: {'learning_rate': 0.07372354538704762, 'max_leaf_nodes': 20, 'min_samples_leaf': 12, 'l2_regularization': 8.840030539590696}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:06,751] Trial 54 finished with value: 0.36388476400816083 and parameters: {'learning_rate': 0.0641653276239603, 'max_leaf_nodes': 26, 'min_samples_leaf': 20, 'l2_regularization': 3.9985742189250018}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:14,627] Trial 55 finished with value: 0.3611931207512374 and parameters: {'learning_rate': 0.041833329324756974, 'max_leaf_nodes': 83, 'min_samples_leaf': 15, 'l2_regularization': 15.032585725196862}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:20,466] Trial 56 finished with value: 0.36321716315282937 and parameters: {'learning_rate': 0.03348996493558976, 'max_leaf_nodes': 29, 'min_samples_leaf': 17, 'l2_regularization': 2.2543243387918404}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:26,644] Trial 57 finished with value: 0.36688084041916563 and parameters: {'learning_rate': 0.05737108125621254, 'max_leaf_nodes': 52, 'min_samples_leaf': 11, 'l2_regularization': 24.041027569839667}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:31,810] Trial 58 finished with value: 0.3635039568788721 and parameters: {'learning_rate': 0.04889627508202382, 'max_leaf_nodes': 22, 'min_samples_leaf': 18, 'l2_regularization': 0.02334740013547816}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:37,047] Trial 59 finished with value: 0.3617362569810553 and parameters: {'learning_rate': 0.05436445088891282, 'max_leaf_nodes': 32, 'min_samples_leaf': 23, 'l2_regularization': 0.0010485990262413287}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:41,949] Trial 60 finished with value: 0.363472362702433 and parameters: {'learning_rate': 0.06874164749042974, 'max_leaf_nodes': 22, 'min_samples_leaf': 13, 'l2_regularization': 0.00362665072633198}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:46,926] Trial 61 finished with value: 0.36923477839176744 and parameters: {'learning_rate': 0.0784242278252465, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 13.130378370818002}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:52,196] Trial 62 finished with value: 0.3638108525638477 and parameters: {'learning_rate': 0.07683357992696965, 'max_leaf_nodes': 26, 'min_samples_leaf': 15, 'l2_regularization': 11.783973101881703}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:35:57,027] Trial 63 finished with value: 0.36942529624592246 and parameters: {'learning_rate': 0.08214447470263567, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'l2_regularization': 7.014566301559133}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:02,176] Trial 64 finished with value: 0.3676592742059551 and parameters: {'learning_rate': 0.08179003923619135, 'max_leaf_nodes': 20, 'min_samples_leaf': 10, 'l2_regularization': 5.7034557864897835}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:07,154] Trial 65 finished with value: 0.3679730334448582 and parameters: {'learning_rate': 0.08363622122031313, 'max_leaf_nodes': 22, 'min_samples_leaf': 11, 'l2_regularization': 11.265874571572757}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:12,415] Trial 66 finished with value: 0.3641970653175566 and parameters: {'learning_rate': 0.07387667791692915, 'max_leaf_nodes': 25, 'min_samples_leaf': 34, 'l2_regularization': 7.031827637454923}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:19,103] Trial 67 finished with value: 0.36586323204839133 and parameters: {'learning_rate': 0.06056957426387788, 'max_leaf_nodes': 68, 'min_samples_leaf': 12, 'l2_regularization': 18.621706116602446}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:24,518] Trial 68 finished with value: 0.3643368058021982 and parameters: {'learning_rate': 0.07895291650687078, 'max_leaf_nodes': 37, 'min_samples_leaf': 29, 'l2_regularization': 13.097441258386356}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:29,333] Trial 69 finished with value: 0.3658454362789353 and parameters: {'learning_rate': 0.08715959975235286, 'max_leaf_nodes': 22, 'min_samples_leaf': 25, 'l2_regularization': 3.342184835802471}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:34,408] Trial 70 finished with value: 0.365263112986126 and parameters: {'learning_rate': 0.07126131100354022, 'max_leaf_nodes': 24, 'min_samples_leaf': 20, 'l2_regularization': 9.626939676464044}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:40,162] Trial 71 finished with value: 0.3676969446508189 and parameters: {'learning_rate': 0.051367029415151796, 'max_leaf_nodes': 28, 'min_samples_leaf': 14, 'l2_regularization': 19.316660195843458}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:45,616] Trial 72 finished with value: 0.36836790201320974 and parameters: {'learning_rate': 0.05741165953874535, 'max_leaf_nodes': 22, 'min_samples_leaf': 11, 'l2_regularization': 8.032529753411835}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:50,795] Trial 73 finished with value: 0.3657686344862419 and parameters: {'learning_rate': 0.05869174051842917, 'max_leaf_nodes': 21, 'min_samples_leaf': 10, 'l2_regularization': 4.609019196497085}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:36:56,319] Trial 74 finished with value: 0.3656146205124128 and parameters: {'learning_rate': 0.056523858121948614, 'max_leaf_nodes': 24, 'min_samples_leaf': 13, 'l2_regularization': 5.571707704111606}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:02,018] Trial 75 finished with value: 0.36614315896432226 and parameters: {'learning_rate': 0.04284699249108709, 'max_leaf_nodes': 20, 'min_samples_leaf': 11, 'l2_regularization': 7.964017749500898}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:07,890] Trial 76 finished with value: 0.36803151551048263 and parameters: {'learning_rate': 0.038717423558143844, 'max_leaf_nodes': 22, 'min_samples_leaf': 16, 'l2_regularization': 24.888593841088717}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:13,637] Trial 77 finished with value: 0.3663875111370905 and parameters: {'learning_rate': 0.04857208612508848, 'max_leaf_nodes': 26, 'min_samples_leaf': 12, 'l2_regularization': 12.437795919413036}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:20,601] Trial 78 finished with value: 0.3600231067434411 and parameters: {'learning_rate': 0.02731847361977963, 'max_leaf_nodes': 58, 'min_samples_leaf': 15, 'l2_regularization': 0.7230080206029292}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:25,560] Trial 79 finished with value: 0.35771420217324057 and parameters: {'learning_rate': 0.06602602476379987, 'max_leaf_nodes': 30, 'min_samples_leaf': 44, 'l2_regularization': 2.3229516686036327}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:30,653] Trial 80 finished with value: 0.3638833704136537 and parameters: {'learning_rate': 0.06236295813520599, 'max_leaf_nodes': 24, 'min_samples_leaf': 22, 'l2_regularization': 8.347031390557241}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:35,787] Trial 81 finished with value: 0.368729296018307 and parameters: {'learning_rate': 0.07510126747304954, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 17.43550667528697}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:40,846] Trial 82 finished with value: 0.3660222607200943 and parameters: {'learning_rate': 0.0758803613537573, 'max_leaf_nodes': 20, 'min_samples_leaf': 13, 'l2_regularization': 19.484711021782555}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:45,950] Trial 83 finished with value: 0.367214334110839 and parameters: {'learning_rate': 0.06992674884359855, 'max_leaf_nodes': 22, 'min_samples_leaf': 10, 'l2_regularization': 12.830489032396626}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:50,629] Trial 84 finished with value: 0.36362342793863933 and parameters: {'learning_rate': 0.07917028177306472, 'max_leaf_nodes': 25, 'min_samples_leaf': 18, 'l2_regularization': 0.19472927969555473}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:37:55,762] Trial 85 finished with value: 0.36535289333796084 and parameters: {'learning_rate': 0.08331664040452627, 'max_leaf_nodes': 27, 'min_samples_leaf': 11, 'l2_regularization': 18.74660468058612}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:00,701] Trial 86 finished with value: 0.3646296967224603 and parameters: {'learning_rate': 0.07300108667776187, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 6.6623623663894636}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:05,859] Trial 87 finished with value: 0.36550599606955664 and parameters: {'learning_rate': 0.06447153556428828, 'max_leaf_nodes': 20, 'min_samples_leaf': 14, 'l2_regularization': 9.784121029700781}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:11,101] Trial 88 finished with value: 0.366941401893386 and parameters: {'learning_rate': 0.052940678337935206, 'max_leaf_nodes': 24, 'min_samples_leaf': 15, 'l2_regularization': 14.412388054613015}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:16,774] Trial 89 finished with value: 0.3670324745026104 and parameters: {'learning_rate': 0.058965053388654584, 'max_leaf_nodes': 33, 'min_samples_leaf': 20, 'l2_regularization': 19.975414460700787}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:21,590] Trial 90 finished with value: 0.36312625927493214 and parameters: {'learning_rate': 0.08627161549413129, 'max_leaf_nodes': 29, 'min_samples_leaf': 16, 'l2_regularization': 3.7970642002629003}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:26,733] Trial 91 finished with value: 0.3685784401407359 and parameters: {'learning_rate': 0.07522368908516713, 'max_leaf_nodes': 21, 'min_samples_leaf': 13, 'l2_regularization': 15.267668173812682}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:31,682] Trial 92 finished with value: 0.3666488648902597 and parameters: {'learning_rate': 0.07537411828525567, 'max_leaf_nodes': 21, 'min_samples_leaf': 13, 'l2_regularization': 10.58697250156746}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:36,659] Trial 93 finished with value: 0.3695997148990983 and parameters: {'learning_rate': 0.08092016416693705, 'max_leaf_nodes': 21, 'min_samples_leaf': 12, 'l2_regularization': 13.104241746907313}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:41,907] Trial 94 finished with value: 0.36703930823132463 and parameters: {'learning_rate': 0.08077740105032047, 'max_leaf_nodes': 26, 'min_samples_leaf': 13, 'l2_regularization': 14.346263012104387}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:46,719] Trial 95 finished with value: 0.3685045054824129 and parameters: {'learning_rate': 0.09280237757403073, 'max_leaf_nodes': 20, 'min_samples_leaf': 37, 'l2_regularization': 16.56563148518344}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:51,647] Trial 96 finished with value: 0.36656068009341747 and parameters: {'learning_rate': 0.07822140688985939, 'max_leaf_nodes': 24, 'min_samples_leaf': 12, 'l2_regularization': 24.761695954986966}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:38:56,505] Trial 97 finished with value: 0.3663890403850426 and parameters: {'learning_rate': 0.07140562360824149, 'max_leaf_nodes': 21, 'min_samples_leaf': 17, 'l2_regularization': 4.985019060003161}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:02,579] Trial 98 finished with value: 0.35738089064275913 and parameters: {'learning_rate': 0.08416538413807817, 'max_leaf_nodes': 81, 'min_samples_leaf': 14, 'l2_regularization': 10.067722870521573}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:07,498] Trial 99 finished with value: 0.3631658605458447 and parameters: {'learning_rate': 0.06891773279361675, 'max_leaf_nodes': 23, 'min_samples_leaf': 15, 'l2_regularization': 0.06073649350714028}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:12,432] Trial 100 finished with value: 0.3612149795178369 and parameters: {'learning_rate': 0.07482984079225535, 'max_leaf_nodes': 27, 'min_samples_leaf': 27, 'l2_regularization': 1.523143982006191}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:17,294] Trial 101 finished with value: 0.3673556353562223 and parameters: {'learning_rate': 0.09263423665301512, 'max_leaf_nodes': 20, 'min_samples_leaf': 36, 'l2_regularization': 16.087342093908177}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:22,349] Trial 102 finished with value: 0.3697434188609977 and parameters: {'learning_rate': 0.07743155961543619, 'max_leaf_nodes': 21, 'min_samples_leaf': 40, 'l2_regularization': 20.782871505736544}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:27,416] Trial 103 finished with value: 0.36994209400655065 and parameters: {'learning_rate': 0.08102319064062705, 'max_leaf_nodes': 22, 'min_samples_leaf': 44, 'l2_regularization': 21.04028361255839}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:32,500] Trial 104 finished with value: 0.36862621229002823 and parameters: {'learning_rate': 0.08911886676807407, 'max_leaf_nodes': 25, 'min_samples_leaf': 45, 'l2_regularization': 20.830340732434518}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:37,518] Trial 105 finished with value: 0.36872415624382493 and parameters: {'learning_rate': 0.07755269984528117, 'max_leaf_nodes': 22, 'min_samples_leaf': 39, 'l2_regularization': 12.441207276046319}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:42,609] Trial 106 finished with value: 0.36623452479974217 and parameters: {'learning_rate': 0.08101654762530992, 'max_leaf_nodes': 23, 'min_samples_leaf': 42, 'l2_regularization': 20.581761709568152}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:47,686] Trial 107 finished with value: 0.3641659206443199 and parameters: {'learning_rate': 0.08549028978372959, 'max_leaf_nodes': 25, 'min_samples_leaf': 48, 'l2_regularization': 6.466268174230152}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:52,581] Trial 108 finished with value: 0.3686436999907796 and parameters: {'learning_rate': 0.08190756175859276, 'max_leaf_nodes': 21, 'min_samples_leaf': 46, 'l2_regularization': 12.495088037660892}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:39:58,631] Trial 109 finished with value: 0.35669836838138985 and parameters: {'learning_rate': 0.07224740420266676, 'max_leaf_nodes': 71, 'min_samples_leaf': 42, 'l2_regularization': 8.956345718593504}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:03,804] Trial 110 finished with value: 0.3674170530223673 and parameters: {'learning_rate': 0.08811037716449291, 'max_leaf_nodes': 29, 'min_samples_leaf': 44, 'l2_regularization': 17.17652121855811}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:08,862] Trial 111 finished with value: 0.36699483108893705 and parameters: {'learning_rate': 0.07779645951217187, 'max_leaf_nodes': 22, 'min_samples_leaf': 39, 'l2_regularization': 12.5040246225001}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:14,006] Trial 112 finished with value: 0.3656597947283177 and parameters: {'learning_rate': 0.07695529352788055, 'max_leaf_nodes': 23, 'min_samples_leaf': 41, 'l2_regularization': 21.59802185649667}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:19,686] Trial 113 finished with value: 0.3629862435234433 and parameters: {'learning_rate': 0.0661856256671828, 'max_leaf_nodes': 48, 'min_samples_leaf': 34, 'l2_regularization': 10.82485918942809}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:24,539] Trial 114 finished with value: 0.3636034370558564 and parameters: {'learning_rate': 0.07948505988367129, 'max_leaf_nodes': 21, 'min_samples_leaf': 40, 'l2_regularization': 7.495605820181693}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:29,577] Trial 115 finished with value: 0.36412683799206397 and parameters: {'learning_rate': 0.08258632713494374, 'max_leaf_nodes': 26, 'min_samples_leaf': 50, 'l2_regularization': 14.132721011944906}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:34,853] Trial 116 finished with value: 0.36904215479266594 and parameters: {'learning_rate': 0.07004467281650509, 'max_leaf_nodes': 23, 'min_samples_leaf': 30, 'l2_regularization': 24.92233335657446}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:39,897] Trial 117 finished with value: 0.36883230000980827 and parameters: {'learning_rate': 0.06838917841983351, 'max_leaf_nodes': 20, 'min_samples_leaf': 31, 'l2_regularization': 24.341899946803945}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:45,203] Trial 118 finished with value: 0.36829584493725304 and parameters: {'learning_rate': 0.06806393875524698, 'max_leaf_nodes': 24, 'min_samples_leaf': 30, 'l2_regularization': 24.939026805838992}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:50,532] Trial 119 finished with value: 0.36767619709956817 and parameters: {'learning_rate': 0.0699966509171931, 'max_leaf_nodes': 23, 'min_samples_leaf': 33, 'l2_regularization': 18.492882286508973}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:40:55,891] Trial 120 finished with value: 0.3671760294953812 and parameters: {'learning_rate': 0.061439738891306925, 'max_leaf_nodes': 27, 'min_samples_leaf': 27, 'l2_regularization': 24.844812806682715}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:00,776] Trial 121 finished with value: 0.3666739370457881 and parameters: {'learning_rate': 0.0733453387506321, 'max_leaf_nodes': 20, 'min_samples_leaf': 29, 'l2_regularization': 17.358517408950615}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:06,001] Trial 122 finished with value: 0.36814085710961547 and parameters: {'learning_rate': 0.06436772341773032, 'max_leaf_nodes': 20, 'min_samples_leaf': 31, 'l2_regularization': 18.237862331525296}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:10,888] Trial 123 finished with value: 0.36904068121981026 and parameters: {'learning_rate': 0.08519762801869288, 'max_leaf_nodes': 22, 'min_samples_leaf': 10, 'l2_regularization': 14.641499072731687}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:15,819] Trial 124 finished with value: 0.3662072516187381 and parameters: {'learning_rate': 0.08579430968254906, 'max_leaf_nodes': 22, 'min_samples_leaf': 10, 'l2_regularization': 9.912345576835532}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:30,314] Trial 125 finished with value: 0.36619404596076827 and parameters: {'learning_rate': 0.005583736810094317, 'max_leaf_nodes': 25, 'min_samples_leaf': 26, 'l2_regularization': 13.871269455265987}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:35,594] Trial 126 finished with value: 0.3658229536666819 and parameters: {'learning_rate': 0.06628021700377293, 'max_leaf_nodes': 23, 'min_samples_leaf': 24, 'l2_regularization': 20.37575319757416}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:41,629] Trial 127 finished with value: 0.36634618318615175 and parameters: {'learning_rate': 0.04435024351920419, 'max_leaf_nodes': 41, 'min_samples_leaf': 37, 'l2_regularization': 11.22720323240435}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:47,234] Trial 128 finished with value: 0.3644180768627113 and parameters: {'learning_rate': 0.04706979205753048, 'max_leaf_nodes': 21, 'min_samples_leaf': 11, 'l2_regularization': 8.583921168458268}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:52,209] Trial 129 finished with value: 0.3640613339784542 and parameters: {'learning_rate': 0.0840598429995467, 'max_leaf_nodes': 24, 'min_samples_leaf': 28, 'l2_regularization': 6.08694563350638}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:41:57,119] Trial 130 finished with value: 0.3699689965542163 and parameters: {'learning_rate': 0.09526227897201525, 'max_leaf_nodes': 22, 'min_samples_leaf': 22, 'l2_regularization': 14.1350716010341}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:01,883] Trial 131 finished with value: 0.36947176430108847 and parameters: {'learning_rate': 0.09496477912265144, 'max_leaf_nodes': 22, 'min_samples_leaf': 22, 'l2_regularization': 13.660510821690206}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:06,787] Trial 132 finished with value: 0.37019114102381223 and parameters: {'learning_rate': 0.09562759094390244, 'max_leaf_nodes': 22, 'min_samples_leaf': 21, 'l2_regularization': 13.799640296342172}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:11,596] Trial 133 finished with value: 0.3690832569798893 and parameters: {'learning_rate': 0.09524354731673323, 'max_leaf_nodes': 22, 'min_samples_leaf': 22, 'l2_regularization': 14.85884090658809}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:16,431] Trial 134 finished with value: 0.3647223669404378 and parameters: {'learning_rate': 0.09652134988433353, 'max_leaf_nodes': 25, 'min_samples_leaf': 21, 'l2_regularization': 9.239003778336045}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:21,077] Trial 135 finished with value: 0.36160439373584036 and parameters: {'learning_rate': 0.09763205662619506, 'max_leaf_nodes': 28, 'min_samples_leaf': 22, 'l2_regularization': 0.2665159347865264}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:26,037] Trial 136 finished with value: 0.3653379577062422 and parameters: {'learning_rate': 0.09078694969586658, 'max_leaf_nodes': 23, 'min_samples_leaf': 22, 'l2_regularization': 12.512733240745504}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:30,804] Trial 137 finished with value: 0.3622210168852961 and parameters: {'learning_rate': 0.09916051554839661, 'max_leaf_nodes': 22, 'min_samples_leaf': 19, 'l2_regularization': 7.624727115227141}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:35,521] Trial 138 finished with value: 0.36701655625011653 and parameters: {'learning_rate': 0.09445982219754147, 'max_leaf_nodes': 24, 'min_samples_leaf': 24, 'l2_regularization': 14.82974522251394}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:40,159] Trial 139 finished with value: 0.36800117409030103 and parameters: {'learning_rate': 0.09552878980645796, 'max_leaf_nodes': 21, 'min_samples_leaf': 21, 'l2_regularization': 10.281147341473432}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:44,862] Trial 140 finished with value: 0.36381508788735517 and parameters: {'learning_rate': 0.09006008536534166, 'max_leaf_nodes': 25, 'min_samples_leaf': 25, 'l2_regularization': 5.3224808010362725}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:49,756] Trial 141 finished with value: 0.36536246768634717 and parameters: {'learning_rate': 0.09988154368134601, 'max_leaf_nodes': 22, 'min_samples_leaf': 20, 'l2_regularization': 13.377226233412244}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:54,829] Trial 142 finished with value: 0.3684381340549975 and parameters: {'learning_rate': 0.09418753795024196, 'max_leaf_nodes': 20, 'min_samples_leaf': 23, 'l2_regularization': 16.05015828151666}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:42:59,730] Trial 143 finished with value: 0.3697468627402025 and parameters: {'learning_rate': 0.09075721663761052, 'max_leaf_nodes': 22, 'min_samples_leaf': 19, 'l2_regularization': 20.291417352025206}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:43:04,976] Trial 144 finished with value: 0.36626166213915506 and parameters: {'learning_rate': 0.09744698655827591, 'max_leaf_nodes': 26, 'min_samples_leaf': 19, 'l2_regularization': 16.654399061141714}. Best is trial 13 with value: 0.3703052760724698.
# [I 2025-05-07 10:43:10,182] Trial 145 finished with value: 0.37086120022377217 and parameters: {'learning_rate': 0.09302858238176509, 'max_leaf_nodes': 23, 'min_samples_leaf': 18, 'l2_regularization': 21.01108583893756}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:15,933] Trial 146 finished with value: 0.3617363499515231 and parameters: {'learning_rate': 0.09210606446375098, 'max_leaf_nodes': 59, 'min_samples_leaf': 18, 'l2_regularization': 20.491500678398687}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:20,722] Trial 147 finished with value: 0.3664296271487695 and parameters: {'learning_rate': 0.08867222596142109, 'max_leaf_nodes': 21, 'min_samples_leaf': 21, 'l2_regularization': 0.012851968873718216}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:26,153] Trial 148 finished with value: 0.3651730627464009 and parameters: {'learning_rate': 0.09418250879184056, 'max_leaf_nodes': 20, 'min_samples_leaf': 22, 'l2_regularization': 11.106128100570066}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:31,849] Trial 149 finished with value: 0.36413362781720876 and parameters: {'learning_rate': 0.09202236655074415, 'max_leaf_nodes': 27, 'min_samples_leaf': 20, 'l2_regularization': 7.392920126903197}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:37,081] Trial 150 finished with value: 0.3655639683415407 and parameters: {'learning_rate': 0.0967936978380284, 'max_leaf_nodes': 24, 'min_samples_leaf': 19, 'l2_regularization': 19.978761843956413}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:43,723] Trial 151 finished with value: 0.3607931141834747 and parameters: {'learning_rate': 0.0953827324284957, 'max_leaf_nodes': 90, 'min_samples_leaf': 18, 'l2_regularization': 20.85205754875582}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:48,840] Trial 152 finished with value: 0.3652838884962531 and parameters: {'learning_rate': 0.09092668889860364, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 13.77916302700786}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:53,871] Trial 153 finished with value: 0.3669553122862376 and parameters: {'learning_rate': 0.09869085907678905, 'max_leaf_nodes': 22, 'min_samples_leaf': 23, 'l2_regularization': 17.412530679259657}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:43:59,024] Trial 154 finished with value: 0.3677924293980443 and parameters: {'learning_rate': 0.0802479966357176, 'max_leaf_nodes': 22, 'min_samples_leaf': 19, 'l2_regularization': 11.38143369489908}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:04,330] Trial 155 finished with value: 0.3683873857176677 and parameters: {'learning_rate': 0.09362750099514652, 'max_leaf_nodes': 21, 'min_samples_leaf': 20, 'l2_regularization': 21.163543876136757}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:09,791] Trial 156 finished with value: 0.3634938157965377 and parameters: {'learning_rate': 0.08916723460620161, 'max_leaf_nodes': 26, 'min_samples_leaf': 16, 'l2_regularization': 24.630478028240383}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:15,080] Trial 157 finished with value: 0.3695405358969154 and parameters: {'learning_rate': 0.08734443533968458, 'max_leaf_nodes': 23, 'min_samples_leaf': 21, 'l2_regularization': 16.002021937086838}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:20,247] Trial 158 finished with value: 0.3643076622386846 and parameters: {'learning_rate': 0.09104971035015019, 'max_leaf_nodes': 20, 'min_samples_leaf': 20, 'l2_regularization': 9.13056889189345}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:25,376] Trial 159 finished with value: 0.3696128148916966 and parameters: {'learning_rate': 0.08759549264421636, 'max_leaf_nodes': 24, 'min_samples_leaf': 22, 'l2_regularization': 14.702491824463774}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:30,549] Trial 160 finished with value: 0.3640943525747833 and parameters: {'learning_rate': 0.08678444811036856, 'max_leaf_nodes': 24, 'min_samples_leaf': 24, 'l2_regularization': 12.254010503974483}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:35,830] Trial 161 finished with value: 0.36418819953255055 and parameters: {'learning_rate': 0.08137664843086492, 'max_leaf_nodes': 23, 'min_samples_leaf': 21, 'l2_regularization': 15.637060227617065}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:41,144] Trial 162 finished with value: 0.3697876756660606 and parameters: {'learning_rate': 0.0880777782686393, 'max_leaf_nodes': 21, 'min_samples_leaf': 23, 'l2_regularization': 17.109767230138846}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:46,464] Trial 163 finished with value: 0.36795382079958916 and parameters: {'learning_rate': 0.08740062630799053, 'max_leaf_nodes': 20, 'min_samples_leaf': 23, 'l2_regularization': 17.914574508365956}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:51,831] Trial 164 finished with value: 0.3664982216841061 and parameters: {'learning_rate': 0.08449873275884753, 'max_leaf_nodes': 21, 'min_samples_leaf': 18, 'l2_regularization': 10.152844550010137}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:44:57,620] Trial 165 finished with value: 0.367586655269027 and parameters: {'learning_rate': 0.08712355345595908, 'max_leaf_nodes': 25, 'min_samples_leaf': 21, 'l2_regularization': 12.756295588970913}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:03,183] Trial 166 finished with value: 0.3675083643615293 and parameters: {'learning_rate': 0.08906440255295306, 'max_leaf_nodes': 22, 'min_samples_leaf': 12, 'l2_regularization': 16.87213652211127}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:08,720] Trial 167 finished with value: 0.3644495177469668 and parameters: {'learning_rate': 0.08207050015875948, 'max_leaf_nodes': 24, 'min_samples_leaf': 22, 'l2_regularization': 8.437722227123587}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:14,353] Trial 168 finished with value: 0.3664487090949903 and parameters: {'learning_rate': 0.08340122323414235, 'max_leaf_nodes': 20, 'min_samples_leaf': 20, 'l2_regularization': 18.816048834374293}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:19,618] Trial 169 finished with value: 0.364882753843185 and parameters: {'learning_rate': 0.09331896781895788, 'max_leaf_nodes': 22, 'min_samples_leaf': 18, 'l2_regularization': 13.153711141938398}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:24,587] Trial 170 finished with value: 0.3624705120936703 and parameters: {'learning_rate': 0.0859826000652277, 'max_leaf_nodes': 24, 'min_samples_leaf': 11, 'l2_regularization': 0.7577197962299578}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:30,043] Trial 171 finished with value: 0.3696267631368552 and parameters: {'learning_rate': 0.09038717739640478, 'max_leaf_nodes': 21, 'min_samples_leaf': 22, 'l2_regularization': 15.038374452402675}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:35,510] Trial 172 finished with value: 0.3637899484664167 and parameters: {'learning_rate': 0.09031456354870163, 'max_leaf_nodes': 21, 'min_samples_leaf': 22, 'l2_regularization': 14.915663360926983}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:41,080] Trial 173 finished with value: 0.36420716096738426 and parameters: {'learning_rate': 0.08794418523078021, 'max_leaf_nodes': 20, 'min_samples_leaf': 23, 'l2_regularization': 10.957880270062883}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:46,583] Trial 174 finished with value: 0.36714111112891323 and parameters: {'learning_rate': 0.0924935043026894, 'max_leaf_nodes': 23, 'min_samples_leaf': 21, 'l2_regularization': 20.87789150390465}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:51,898] Trial 175 finished with value: 0.3658598394381121 and parameters: {'learning_rate': 0.08008717680886304, 'max_leaf_nodes': 20, 'min_samples_leaf': 25, 'l2_regularization': 16.791054403344027}. Best is trial 145 with value: 0.37086120022377217.
# [I 2025-05-07 10:45:57,237] Trial 176 finished with value: 0.36409432106478024 and parameters: {'learning_rate': 0.09007994567298706, 'max_leaf_nodes': 22, 'min_samples_leaf': 21, 'l2_regularization': 11.666866285009053}. Best is trial 145 with value: 0.37086120022377217.
# ...
# [I 2025-05-07 10:56:47,466] Trial 292 finished with value: 0.36544162359809274 and parameters: {'learning_rate': 0.05770466616838201, 'max_leaf_nodes': 22, 'min_samples_leaf': 26, 'l2_regularization': 11.962265958135626}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:56:52,474] Trial 293 finished with value: 0.36620166113194186 and parameters: {'learning_rate': 0.060368851247137305, 'max_leaf_nodes': 20, 'min_samples_leaf': 41, 'l2_regularization': 14.720707525333086}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:56:58,290] Trial 294 finished with value: 0.3590346698038573 and parameters: {'learning_rate': 0.07485708361921672, 'max_leaf_nodes': 79, 'min_samples_leaf': 40, 'l2_regularization': 18.26941195381853}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:03,522] Trial 295 finished with value: 0.3646258661529338 and parameters: {'learning_rate': 0.06363854458948094, 'max_leaf_nodes': 24, 'min_samples_leaf': 44, 'l2_regularization': 10.822718219322411}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:08,386] Trial 296 finished with value: 0.3677050694774823 and parameters: {'learning_rate': 0.09444642071467774, 'max_leaf_nodes': 21, 'min_samples_leaf': 18, 'l2_regularization': 24.87018964253686}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:13,199] Trial 297 finished with value: 0.36720142748925555 and parameters: {'learning_rate': 0.09008660724226451, 'max_leaf_nodes': 22, 'min_samples_leaf': 46, 'l2_regularization': 14.105632697796045}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:18,032] Trial 298 finished with value: 0.3660915977752017 and parameters: {'learning_rate': 0.09235973287474267, 'max_leaf_nodes': 21, 'min_samples_leaf': 17, 'l2_regularization': 0.07984198585995679}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:23,957] Trial 299 finished with value: 0.36269381486836993 and parameters: {'learning_rate': 0.0650696831747675, 'max_leaf_nodes': 62, 'min_samples_leaf': 45, 'l2_regularization': 19.595882564881094}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:28,903] Trial 300 finished with value: 0.36460389236339535 and parameters: {'learning_rate': 0.08454311049687689, 'max_leaf_nodes': 23, 'min_samples_leaf': 39, 'l2_regularization': 8.06452511096376}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:33,669] Trial 301 finished with value: 0.36831804336547147 and parameters: {'learning_rate': 0.098054729884835, 'max_leaf_nodes': 20, 'min_samples_leaf': 43, 'l2_regularization': 17.203463589696877}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:38,837] Trial 302 finished with value: 0.3683542121983129 and parameters: {'learning_rate': 0.06966480573177533, 'max_leaf_nodes': 25, 'min_samples_leaf': 38, 'l2_regularization': 12.528203961877447}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:43,747] Trial 303 finished with value: 0.3703722188770626 and parameters: {'learning_rate': 0.08793379392956893, 'max_leaf_nodes': 22, 'min_samples_leaf': 19, 'l2_regularization': 20.89154343489793}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:48,689] Trial 304 finished with value: 0.3669432465285675 and parameters: {'learning_rate': 0.08792330156322256, 'max_leaf_nodes': 24, 'min_samples_leaf': 20, 'l2_regularization': 21.152970475054598}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:53,712] Trial 305 finished with value: 0.3657557339411185 and parameters: {'learning_rate': 0.08979979520628496, 'max_leaf_nodes': 22, 'min_samples_leaf': 19, 'l2_regularization': 21.1493295613329}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:57:58,772] Trial 306 finished with value: 0.36780582339784373 and parameters: {'learning_rate': 0.09369759997501667, 'max_leaf_nodes': 27, 'min_samples_leaf': 18, 'l2_regularization': 16.06252231783059}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:03,774] Trial 307 finished with value: 0.3658162211811058 and parameters: {'learning_rate': 0.08823851917743065, 'max_leaf_nodes': 23, 'min_samples_leaf': 19, 'l2_regularization': 20.700742550074423}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:08,635] Trial 308 finished with value: 0.3682064459402068 and parameters: {'learning_rate': 0.09115050019794023, 'max_leaf_nodes': 20, 'min_samples_leaf': 24, 'l2_regularization': 16.54241717667246}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:14,000] Trial 309 finished with value: 0.36869912120642895 and parameters: {'learning_rate': 0.061762302449757625, 'max_leaf_nodes': 22, 'min_samples_leaf': 32, 'l2_regularization': 21.8688624449495}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:19,247] Trial 310 finished with value: 0.36758650604804427 and parameters: {'learning_rate': 0.08608603187266048, 'max_leaf_nodes': 25, 'min_samples_leaf': 22, 'l2_regularization': 17.680326232786268}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:24,067] Trial 311 finished with value: 0.36910621609703853 and parameters: {'learning_rate': 0.0956829759094254, 'max_leaf_nodes': 20, 'min_samples_leaf': 48, 'l2_regularization': 13.981909385991813}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:29,043] Trial 312 finished with value: 0.3687281267667065 and parameters: {'learning_rate': 0.09966530548565272, 'max_leaf_nodes': 22, 'min_samples_leaf': 20, 'l2_regularization': 24.5550670211514}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:34,448] Trial 313 finished with value: 0.361380660198976 and parameters: {'learning_rate': 0.04828543772266652, 'max_leaf_nodes': 23, 'min_samples_leaf': 21, 'l2_regularization': 1.4140665615256205}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:39,376] Trial 314 finished with value: 0.36716112493810515 and parameters: {'learning_rate': 0.06694192048416968, 'max_leaf_nodes': 21, 'min_samples_leaf': 23, 'l2_regularization': 10.821425819504084}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:44,382] Trial 315 finished with value: 0.3682643719017548 and parameters: {'learning_rate': 0.09146047811089433, 'max_leaf_nodes': 24, 'min_samples_leaf': 40, 'l2_regularization': 18.021000795608757}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:49,325] Trial 316 finished with value: 0.36814800595230607 and parameters: {'learning_rate': 0.09325989394125948, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 14.437616662027818}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:54,479] Trial 317 finished with value: 0.3713671359157743 and parameters: {'learning_rate': 0.06328254626185774, 'max_leaf_nodes': 22, 'min_samples_leaf': 17, 'l2_regularization': 19.21836363704397}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:58:59,777] Trial 318 finished with value: 0.3683216144487649 and parameters: {'learning_rate': 0.06351783361781449, 'max_leaf_nodes': 21, 'min_samples_leaf': 16, 'l2_regularization': 20.87364939139217}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:05,301] Trial 319 finished with value: 0.3665584890698316 and parameters: {'learning_rate': 0.06104062334876866, 'max_leaf_nodes': 22, 'min_samples_leaf': 17, 'l2_regularization': 18.322803581875647}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:10,528] Trial 320 finished with value: 0.36682760490581356 and parameters: {'learning_rate': 0.06622870593710277, 'max_leaf_nodes': 20, 'min_samples_leaf': 18, 'l2_regularization': 24.589402441460518}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:15,922] Trial 321 finished with value: 0.3698933559381232 and parameters: {'learning_rate': 0.06438310135767758, 'max_leaf_nodes': 22, 'min_samples_leaf': 18, 'l2_regularization': 16.599909075695535}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:21,239] Trial 322 finished with value: 0.36542419211898813 and parameters: {'learning_rate': 0.06356290929473622, 'max_leaf_nodes': 21, 'min_samples_leaf': 18, 'l2_regularization': 18.756731104368306}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:26,284] Trial 323 finished with value: 0.3640796330682159 and parameters: {'learning_rate': 0.05909076086376578, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 0.001884544142403627}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:31,461] Trial 324 finished with value: 0.37026583028869225 and parameters: {'learning_rate': 0.0662409332475517, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'l2_regularization': 20.342345313155455}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:36,704] Trial 325 finished with value: 0.36853350332390533 and parameters: {'learning_rate': 0.06548065010678598, 'max_leaf_nodes': 20, 'min_samples_leaf': 16, 'l2_regularization': 20.59343894711357}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:41,568] Trial 326 finished with value: 0.36483574587009415 and parameters: {'learning_rate': 0.06654293666457073, 'max_leaf_nodes': 22, 'min_samples_leaf': 15, 'l2_regularization': 0.24359261041626806}. Best is trial 217 with value: 0.37201123643592593.
# [I 2025-05-07 10:59:46,951] Trial 327 finished with value: 0.37253694641539103 and parameters: {'learning_rate': 0.06394868766799867, 'max_leaf_nodes': 20, 'min_samples_leaf': 17, 'l2_regularization': 22.128602074859426}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 10:59:52,490] Trial 328 finished with value: 0.36792833750837384 and parameters: {'learning_rate': 0.061446942200630614, 'max_leaf_nodes': 22, 'min_samples_leaf': 16, 'l2_regularization': 23.92139856219225}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 10:59:57,750] Trial 329 finished with value: 0.36924310143607114 and parameters: {'learning_rate': 0.06466575547344806, 'max_leaf_nodes': 20, 'min_samples_leaf': 18, 'l2_regularization': 24.878018267772894}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:03,014] Trial 330 finished with value: 0.36783131867280805 and parameters: {'learning_rate': 0.06821979206308391, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 24.744673893046958}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:08,153] Trial 331 finished with value: 0.36618490622976146 and parameters: {'learning_rate': 0.07205218262944285, 'max_leaf_nodes': 25, 'min_samples_leaf': 19, 'l2_regularization': 17.29231031322177}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:13,254] Trial 332 finished with value: 0.3690887396482069 and parameters: {'learning_rate': 0.07049500047359374, 'max_leaf_nodes': 21, 'min_samples_leaf': 18, 'l2_regularization': 19.542823687228772}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:18,872] Trial 333 finished with value: 0.36681497293467397 and parameters: {'learning_rate': 0.06248862997260734, 'max_leaf_nodes': 24, 'min_samples_leaf': 19, 'l2_regularization': 12.54807220098258}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:24,055] Trial 334 finished with value: 0.36800655199070675 and parameters: {'learning_rate': 0.06836057780410916, 'max_leaf_nodes': 22, 'min_samples_leaf': 18, 'l2_regularization': 15.685298015970767}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:29,194] Trial 335 finished with value: 0.37003386419115614 and parameters: {'learning_rate': 0.06534154665124602, 'max_leaf_nodes': 20, 'min_samples_leaf': 20, 'l2_regularization': 24.93125840840317}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:34,826] Trial 336 finished with value: 0.36284605187526403 and parameters: {'learning_rate': 0.06651097045872363, 'max_leaf_nodes': 44, 'min_samples_leaf': 20, 'l2_regularization': 21.277921508552396}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:40,106] Trial 337 finished with value: 0.3660497602292917 and parameters: {'learning_rate': 0.06505013797297327, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 24.943779538797784}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:45,523] Trial 338 finished with value: 0.3721541645459441 and parameters: {'learning_rate': 0.06299200878209602, 'max_leaf_nodes': 20, 'min_samples_leaf': 17, 'l2_regularization': 24.922621301696072}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:50,555] Trial 339 finished with value: 0.36946307498494346 and parameters: {'learning_rate': 0.0678226759832636, 'max_leaf_nodes': 21, 'min_samples_leaf': 16, 'l2_regularization': 20.957888602098617}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:00:58,402] Trial 340 finished with value: 0.3637064577025045 and parameters: {'learning_rate': 0.01138738089206974, 'max_leaf_nodes': 20, 'min_samples_leaf': 15, 'l2_regularization': 0.0010615862958761422}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:03,702] Trial 341 finished with value: 0.36623656466587856 and parameters: {'learning_rate': 0.0632849075036744, 'max_leaf_nodes': 23, 'min_samples_leaf': 17, 'l2_regularization': 24.655259988173217}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:08,885] Trial 342 finished with value: 0.36954754763935266 and parameters: {'learning_rate': 0.06437070865114826, 'max_leaf_nodes': 22, 'min_samples_leaf': 17, 'l2_regularization': 24.873285165585113}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:14,459] Trial 343 finished with value: 0.3711170498977394 and parameters: {'learning_rate': 0.060548338554806486, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 17.879915954185133}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:20,261] Trial 344 finished with value: 0.36818617326254094 and parameters: {'learning_rate': 0.059177552094901074, 'max_leaf_nodes': 20, 'min_samples_leaf': 18, 'l2_regularization': 19.980286357470554}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:26,220] Trial 345 finished with value: 0.36784641413522656 and parameters: {'learning_rate': 0.056528140774682184, 'max_leaf_nodes': 35, 'min_samples_leaf': 16, 'l2_regularization': 18.456653784295394}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:31,539] Trial 346 finished with value: 0.3686389501542178 and parameters: {'learning_rate': 0.06022299350510676, 'max_leaf_nodes': 23, 'min_samples_leaf': 19, 'l2_regularization': 16.83511800519128}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:36,706] Trial 347 finished with value: 0.3607239926362744 and parameters: {'learning_rate': 0.06189861675689634, 'max_leaf_nodes': 26, 'min_samples_leaf': 42, 'l2_regularization': 1.0037729118570504}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:43,818] Trial 348 finished with value: 0.36344561041773976 and parameters: {'learning_rate': 0.058035510051392014, 'max_leaf_nodes': 53, 'min_samples_leaf': 19, 'l2_regularization': 20.80375722408348}. Best is trial 327 with value: 0.37253694641539103.
# [I 2025-05-07 11:01:50,160] Trial 349 finished with value: 0.37024492050449254 and parameters: {'learning_rate': 0.05077713482904398, 'max_leaf_nodes': 21, 'min_samples_leaf': 17, 'l2_regularization': 16.702985745071587}. Best is trial 327 with value: 0.37253694641539103.

# %%
top_trials = sorted(study.trials, key=lambda t: t.value, reverse=True)[:5]  # For minimization
# or reverse=True if you're maximizing

# Print parameters of top trials
for i, trial in enumerate(top_trials, 1):
    print(f"Top {i}:")
    print(f"  Value: {trial.value}")
    print(f"  Params: {trial.params}")
# Out:
# Top 1:
#   Value: 0.37253694641539103
#   Params: {'learning_rate': 0.06394868766799867, 'max_leaf_nodes': 20, 'min_samples_leaf': 17, 'l2_regularization': 22.128602074859426}
# Top 2:
#   Value: 0.3721541645459441
#   Params: {'learning_rate': 0.06299200878209602, 'max_leaf_nodes': 20, 'min_samples_leaf': 17, 'l2_regularization': 24.922621301696072}
# Top 3:
#   Value: 0.37201123643592593
#   Params: {'learning_rate': 0.0625476138426423, 'max_leaf_nodes': 20, 'min_samples_leaf': 21, 'l2_regularization': 20.89855368117552}
# Top 4:
#   Value: 0.3713671359157743
#   Params: {'learning_rate': 0.06328254626185774, 'max_leaf_nodes': 22, 'min_samples_leaf': 17, 'l2_regularization': 19.21836363704397}
# Top 5:
#   Value: 0.3711170498977394
#   Params: {'learning_rate': 0.060548338554806486, 'max_leaf_nodes': 20, 'min_samples_leaf': 19, 'l2_regularization': 17.879915954185133}

# %%
# difference_min, info_min = study.best_trial.user_attrs['difference_min'], study.best_trial.user_attrs['info_min']
difference_min, info_min = 0.05, 0.03

presence_info_df_3 = presence_info_df_3[(np.abs(presence_info_df_3['difference']) > difference_min) & (presence_info_df_3['info'] > info_min)]
presence_info_df = presence_info_df_3

updated_train_df = add_presence_columns(train_df, presence_info_df)
updated_test_df = add_presence_columns(test_df, presence_info_df)

present_cols = [col for col in updated_train_df.columns if col.endswith('_present')]
# print(updated_train_df[non_present_cols].info())


high_dim_cat_cols_to_drop = ['claim_date.day', 'claim_date.dayofweek', 'claim_date.weekofyear', 'claim_date.month']
updated_train_df.drop(columns = high_dim_cat_cols_to_drop, inplace=True)
updated_test_df.drop(columns = high_dim_cat_cols_to_drop, inplace=True)

# Step 1: Fit on training data
onehot, scaler, cat_cols, num_cols = fit_regular_transformer(updated_train_df)

# Step 2: Transform training set itself
X_train_regular = transform_regular_set(updated_train_df, onehot, scaler, cat_cols, num_cols)

# Step 3: Transform test set (call the same function on test_df)
X_test_regular = transform_regular_set(test_df, onehot, scaler, cat_cols, num_cols)

# present_cols = []
# Combine for train
updated_train_final = pd.concat([X_train_regular, updated_train_df[present_cols]], axis=1)

# Combine for test
updated_test_final = pd.concat([X_test_regular, updated_test_df[present_cols]], axis=1)

# %%
# Paths
import json
output_dir = '../Records/hgbc_temp'
train_csv_path = os.path.join(output_dir, 'train_2025.csv')
test_csv_path = os.path.join(output_dir, 'test_2025.csv')
param_json_path = os.path.join(output_dir, 'param_hgbc_temp.json')

# Ensure output directory exists
os.makedirs(output_dir, exist_ok=True)

# Save DataFrames
train_df.to_csv(train_csv_path, index=False)
print(f"Saved train DataFrame to {train_csv_path}")

test_df.to_csv(test_csv_path, index=False)
print(f"Saved test DataFrame to {test_csv_path}")

# Save best_params as JSON
best_threshold = study.best_trial.user_attrs['mean_threshold']
best_params = study.best_params
best_params.update({'mean_threshold': float(best_threshold)})
with open(param_json_path, 'w') as f:
    json.dump(best_params, f, indent=4)
print(f"Saved best parameters to {param_json_path}")
# Out:
# Saved train DataFrame to ../Records/hgbc_temp\train_2025.csv
# Saved test DataFrame to ../Records/hgbc_temp\test_2025.csv
# Saved best parameters to ../Records/hgbc_temp\param_hgbc_temp.json

# %%
# Split train into final train and validation sets
X_train_final, X_val_final, y_train_final, y_val_final = train_test_split(
    updated_train_final, target, test_size=0.01, stratify=target, random_state=42
)

# Combine train and validation (since HGBC handles splitting internally)
X_full = pd.concat([X_train_final, X_val_final])
y_full = pd.concat([y_train_final, y_val_final])

# Define HGBC parameters (you can include your tuned params here if needed)
hgbc_params = {
    'max_iter': 5000,               # similar to num_boost_round
    'learning_rate': best_params.get('learning_rate', 0.1),
    'max_leaf_nodes': best_params.get('num_leaves', 31),  # LightGBM num_leaves ~ HGBC max_leaf_nodes
    'max_depth': best_params.get('max_depth', None),      # Optional
    'l2_regularization': best_params.get('lambda_l2', 0.0),
    'early_stopping': True,
    'validation_fraction': len(X_val_final) / len(X_full),
    'n_iter_no_change': 100,       # early_stopping_rounds
    'random_state': 69,
    'verbose': 0
}

# Initialize and fit the model
hgbc = HistGradientBoostingClassifier(**hgbc_params)


hgbc.fit(X_full, y_full)

# Predict probabilities on test set
probs_test = hgbc.predict_proba(updated_test_final)[:, 1]

# %%
timestamp = datetime.now().strftime('%m%d_%H%M')

final_preds = (probs_test > best_threshold).astype(int)

submission = pd.DataFrame({
    'claim_number': test_id,
    'fraud': final_preds
})

submission.to_csv(f'../Records/hgbc_temp/submission_temp.csv', index=False)
