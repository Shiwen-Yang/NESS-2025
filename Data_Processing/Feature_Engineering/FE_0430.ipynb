# %%
import pandas as pd
import numpy as np
import sys
import os

# Add the grandparent directory to sys.path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))
from Utils import FE_helper as FE
# Out:
# c:\Users\yangs\.conda\envs\myenv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# 2. Load the data
train_df_25 = pd.read_csv('../../Data/original/train_2025.csv') 
train_df_25['xxx'] = 1
train_df_23 = pd.read_csv(r"C:/Users/yangs/Desktop/train_2023.csv")
train_df_23['xxx'] = 0

train_df = pd.concat([train_df_23, train_df_25], ignore_index=True)

test_df = pd.read_csv('../../Data/original/test_2025.csv')
test_df['xxx'] = 1

# %%
train_df = FE.preprocessing(train_df)
test_df = FE.preprocessing(test_df)

# %%
train_df.to_csv(r'../../Data/processed/0430_01/train_2025.csv', index=False)
test_df.to_csv(r'../../Data/processed/0430_01/test_2025.csv', index=False)

# %%
ignore_var = ['claim_number', 'fraud', 'claim_date.month', 'claim_date.day', 'claim_date.dayofweek', 'claim_date.weekofyear']

# %%
numeric_cols = train_df.select_dtypes(include=np.number).columns
numeric_cols = [col for col in numeric_cols if col not in ignore_var]

numeric_df = train_df[numeric_cols]

# %%
numeric_df
# Out:
#        age_of_driver  marital_status  safty_rating  annual_income  \
# 0                 50               1            66          39117
# 1                 47               1            78          38498
# 2                 28               0            76          33343
# 3                 36               1            56          35832
# 4                 60               1            79          40948
# ...              ...             ...           ...            ...
# 36995             43               1            65          97505
# 36996             33               0            65          81642
# 36997             39               0            84         123385
# 36998             49               0            89          91848
# 36999             48               1            65         114306
#
#        high_education_ind  address_change_ind  past_num_of_claims  liab_prct  \
# 0                       1                   0                   0         18
# ...

# %%
other_cols = train_df.select_dtypes(include=object).columns
other_cols = [col for col in other_cols if col not in ignore_var]

other_df = train_df[other_cols]

# %%
other_df
# Out:
#       gender living_status accident_site witness_present_ind channel  \
# 0          F           Own         Local                 0.0  Broker
# 1          M           Own   Parking Lot                 0.0  Broker
# 2          M          Rent         Local                 1.0  Broker
# 3          M           Own         Local                 1.0   Phone
# 4          F          Rent       Highway                 0.0   Phone
# ...      ...           ...           ...                 ...     ...
# 36995      F           Own         Local                 0.0  Broker
# 36996      F           Own         Local                 0.0  Broker
# 36997      M           Own         Local                 1.0  Broker
# 36998      F          Rent         Local                 1.0  Broker
# 36999      M           Own   Parking Lot                 0.0  Broker
#
#       vehicle_category vehicle_color age_group claim_date.year  \
# 0                Large          blue         D            2016
# ...
